# %% [markdown]
# <a href="https://colab.research.google.com/github/Damjanv1/Sideprojects/blob/main/Workouts_Wayback_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install libraries needed
pip install requests beautifulsoup4 pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # Workouts (WOD)

# %%
####### this is the code that ran
### code to scraoe data for timestamp 20180210001310 (return and change to get other workouts)
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random

class WorkoutScraper:
    def __init__(self):
        self.base_url = "https://web.archive.org/web/"
        self.workouts = []
        self.categories = {
            '94': 'Strength WODs',
            '95': 'Skill WODs',
            '96': 'Flexibility WODs',
            '97': 'MetCon WODs'
        }
        self.timestamps = [
            "20180210001310",
            "20180818133346",
            "20130806050456",
            "20130801000000",
            "20130701000000"
        ]

    def get_valid_timestamp(self, focus_tid):
        """Find a working timestamp for this category"""
        for timestamp in self.timestamps:
            url = f"{self.base_url}{timestamp}/http://gymnasticswod.com/wod?field_focus_tid={focus_tid}"
            try:
                print(f"Testing timestamp {timestamp} for category {focus_tid}...")
                response = requests.get(url, timeout=10)
                if response.status_code == 200:
                    print(f"Found working timestamp: {timestamp}")
                    return timestamp
                time.sleep(5)  # Delay between timestamp tests
            except requests.RequestException:
                continue
        return self.timestamps[0]  # Default to first timestamp if none work

    def get_page_content(self, url, retry_count=3):
        """Get page content with error handling"""
        for attempt in range(retry_count):
            try:
                print(f"Fetching: {url}")
                response = requests.get(url, timeout=15)
                response.raise_for_status()
                if response.status_code == 200:
                    return response.text
            except requests.RequestException as e:
                print(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt + 1 == retry_count:
                    print(f"Failed to fetch {url}")
                    return None
                delay = (2 ** attempt) * 5 + random.uniform(1, 5)
                print(f"Waiting {delay:.1f} seconds before retry...")
                time.sleep(delay)
        return None

    def clean_workout_text(self, text):
        """Clean up the workout text"""
        text = text.replace('Workout', '')
        text = text.replace('WorkoutFor', 'For')
        text = text.split('Add new comment')[0]
        text = text.split('Post your experience')[0]
        lines = [line.strip() for line in text.split('\n')]
        lines = [line for line in lines if line and not line.isspace()]
        return '\n'.join(lines)

    def parse_workout(self, soup, category):
        """Parse workout information from the page"""
        workouts = []
        sections = soup.find_all(['h2', 'h3'])

        for section in sections:
            if any(day in section.text.lower() for day in ['mon', 'tue', 'wed', 'thu', 'fri', 'sat', 'sun']):
                date = section.text.strip()
                workout_content = None
                current = section.find_next_sibling()

                while current and not workout_content:
                    if 'Workout' in current.text:
                        workout_content = current.text
                    current = current.find_next_sibling()

                if workout_content:
                    clean_content = self.clean_workout_text(workout_content)

                    workout_type = ''
                    if 'FOR QUALITY' in clean_content.upper():
                        workout_type = 'FOR QUALITY'
                    elif 'ROUNDS' in clean_content.upper():
                        workout_type = 'ROUNDS'
                    elif 'AMRAP' in clean_content.upper():
                        workout_type = 'AMRAP'
                    elif 'FOR TIME' in clean_content.upper():
                        workout_type = 'FOR TIME'

                    workout = {
                        'date': date,
                        'category': category,
                        'workout_type': workout_type,
                        'workout': clean_content
                    }

                    workouts.append(workout)
                    print(f"Found workout for {date}")

        return workouts

    def scrape_category(self, focus_tid, category_name):
        """Scrape all pages for a given category"""
        timestamp = self.get_valid_timestamp(focus_tid)
        page = 0
        category_count = 0

        while True:
            base_url = f"http://gymnasticswod.com/wod?field_focus_tid={focus_tid}"
            if page > 0:
                base_url += f"&sort_by=created&sort_order=DESC&page={page}"

            url = f"{self.base_url}{timestamp}/{base_url}"
            print(f"\nProcessing {category_name} - Page {page}")

            content = self.get_page_content(url)
            if not content:
                break

            soup = BeautifulSoup(content, 'html.parser')
            page_workouts = self.parse_workout(soup, category_name)

            if not page_workouts:
                print(f"No more workouts found on page {page}")
                break

            self.workouts.extend(page_workouts)
            category_count += len(page_workouts)
            print(f"Found {len(page_workouts)} workouts on page {page}")
            print(f"Total {category_name} workouts: {category_count}")

            next_page = soup.find('a', text='next ›')
            if not next_page:
                print("No more pages found")
                break

            page += 1
            delay = random.uniform(8, 12)
            print(f"Waiting {delay:.1f} seconds before next page...")
            time.sleep(delay)

    def scrape_all_categories(self):
        """Scrape workouts from all categories"""
        for focus_tid, category_name in self.categories.items():
            print(f"\nScraping {category_name}...")
            initial_count = len(self.workouts)
            self.scrape_category(focus_tid, category_name)
            final_count = len(self.workouts)
            print(f"Added {final_count - initial_count} {category_name}")

            delay = random.uniform(15, 20)
            print(f"Waiting {delay:.1f} seconds before next category...")
            time.sleep(delay)

    def save_to_csv(self, filename='workouts.csv'):
        """Save workouts to CSV file"""
        df = pd.DataFrame(self.workouts)
        df.to_csv(filename, index=False)
        print(f"\nSaved {len(self.workouts)} workouts to {filename}")
        print("\nWorkouts by category:")
        print(df['category'].value_counts())
        print("\nWorkout types:")
        print(df['workout_type'].value_counts())

def main():
    scraper = WorkoutScraper()
    try:
        print("Starting full workout scrape...")
        scraper.scrape_all_categories()
        scraper.save_to_csv()

    except KeyboardInterrupt:
        print("\nScraping interrupted by user!")
        if scraper.workouts:
            scraper.save_to_csv('workouts_partial.csv')
            print("Partial results saved!")
    except Exception as e:
        print(f"\nAn error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        if scraper.workouts:
            scraper.save_to_csv('workouts_error.csv')
            print("Partial results saved due to error!")

if __name__ == "__main__":
    main()
# Out:
# Starting full workout scrape...
#
# Scraping Strength WODs...
# Testing timestamp 20180210001310 for category 94...
# Found working timestamp: 20180210001310
#
# Processing Strength WODs - Page 0
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94
# Found workout for Tue 12/29
# Found workout for Fri 12/25
# Found workout for Mon 12/21
# Found workout for Thu 12/17
# Found workout for Sun 12/13
# Found workout for Wed 12/09
# Found workout for Sat 12/05
# Found workout for Tue 12/01
# Found workout for Fri 11/27
# Found workout for Mon 11/23
# Found 10 workouts on page 0
# Total Strength WODs workouts: 10
# Waiting 8.1 seconds before next page...
# <ipython-input-25-4355f89302cd>:140: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   next_page = soup.find('a', text='next ›')
# Processing Strength WODs - Page 1
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=1
# Found workout for Thu 11/19
# Found workout for Sun 11/15
# Found workout for Wed 11/11
# Found workout for Sat 11/07
# Found workout for Tue 11/03
# Found workout for Fri 10/30
# Found workout for Mon 10/25
# Found workout for Thu 10/22
# Found workout for Sun 10/18
# Found workout for Wed 10/14
# Found 10 workouts on page 1
# Total Strength WODs workouts: 20
# Waiting 8.1 seconds before next page...
#
# Processing Strength WODs - Page 2
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=2
# Found workout for Sat 10/10
# Found workout for Tue 10/06
# Found workout for Fri 10/02
# Found workout for Mon 09/28
# Found workout for Thu 09/24
# Found workout for Sun 09/20
# Found workout for Wed 09/16
# Found workout for Sat 09/12
# Found workout for Tue 09/08
# Found workout for Fri 09/04
# Found 10 workouts on page 2
# Total Strength WODs workouts: 30
# Waiting 11.0 seconds before next page...
#
# Processing Strength WODs - Page 3
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=3
# Found workout for Mon 08/31
# Found workout for Thu 08/27
# Found workout for Sun 08/23
# Found workout for Wed 08/19
# Found workout for Sat 08/15
# Found workout for Tue 08/11
# Found workout for Fri 08/07
# Found workout for Mon 08/03
# Found workout for Thu 07/30
# Found workout for Sun 07/26
# Found 10 workouts on page 3
# Total Strength WODs workouts: 40
# Waiting 8.1 seconds before next page...
#
# Processing Strength WODs - Page 4
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=4
# Found workout for Wed 07/22
# Found workout for Sat 07/18
# Found workout for Tue 07/14
# Found workout for Fri 07/10
# Found workout for Mon 07/06
# Found workout for Thu 07/02
# Found workout for Sun 06/28
# Found workout for Wed 06/24
# Found workout for Sat 06/20
# Found workout for Tue 06/16
# Found 10 workouts on page 4
# Total Strength WODs workouts: 50
# Waiting 9.7 seconds before next page...
#
# Processing Strength WODs - Page 5
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=5
# Found workout for Fri 06/12
# Found workout for Mon 06/08
# Found workout for Thu 06/04
# Found workout for Sun 05/31
# Found workout for Wed 05/27
# Found workout for Sat 05/23
# Found workout for Tue 05/19
# Found workout for Fri 05/15
# Found workout for Mon 05/11
# Found workout for Thu 05/07
# Found 10 workouts on page 5
# Total Strength WODs workouts: 60
# Waiting 8.4 seconds before next page...
#
# Processing Strength WODs - Page 6
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=6
# Found workout for Sun 05/03
# Found workout for Wed 04/29
# Found workout for Sat 04/25
# Found workout for Tue 04/21
# Found workout for Fri 04/17
# Found workout for Mon 04/13
# Found workout for Thu 04/09
# Found workout for Sun 04/05
# Found workout for Wed 04/01
# Found workout for Sat 03/28
# Found 10 workouts on page 6
# Total Strength WODs workouts: 70
# Waiting 8.1 seconds before next page...
#
# Processing Strength WODs - Page 7
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=7
# Found workout for Tue 03/24
# Found workout for Fri 03/20
# Found workout for Mon 03/16
# Found workout for Thu 03/12
# Found workout for Sun 03/08
# Found workout for Wed 03/04
# Found workout for Sat 02/28
# Found workout for Tue 02/24
# Found workout for Fri 02/20
# Found workout for Mon 02/16
# Found 10 workouts on page 7
# Total Strength WODs workouts: 80
# Waiting 9.5 seconds before next page...
#
# Processing Strength WODs - Page 8
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=8
# Found workout for Wed 02/11
# Found workout for Sat 02/07
# Found workout for Tue 02/03
# Found workout for Fri 01/30
# Found workout for Mon 01/26
# Found workout for Thu 01/22
# Found workout for Sun 01/18
# Found workout for Wed 01/14
# Found workout for Sat 01/10
# Found workout for Tue 01/06
# Found 10 workouts on page 8
# Total Strength WODs workouts: 90
# Waiting 9.8 seconds before next page...
#
# Processing Strength WODs - Page 9
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=9
# Found workout for Fri 01/02
# Found workout for Mon 12/29
# Found workout for Thu 12/25
# Found workout for Sun 12/21
# Found workout for Wed 12/17
# Found workout for Sat 12/13
# Found workout for Tue 12/09
# Found workout for Fri 12/05
# Found workout for Mon 12/01
# Found workout for Thu 11/27
# Found 10 workouts on page 9
# Total Strength WODs workouts: 100
# Waiting 12.0 seconds before next page...
#
# Processing Strength WODs - Page 10
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=10
# Found workout for Tue 11/25
# Found workout for Fri 11/21
# Found workout for Mon 11/17
# Found workout for Thu 11/13
# Found workout for Sun 11/09
# Found workout for Wed 11/05
# Found workout for Sat 11/01
# Found workout for Tue 10/28
# Found workout for Fri 10/24
# Found workout for Mon 10/20
# Found 10 workouts on page 10
# Total Strength WODs workouts: 110
# Waiting 8.5 seconds before next page...
#
# Processing Strength WODs - Page 11
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=11
# Found workout for Thu 10/16
# Found workout for Sun 10/12
# Found workout for Wed 10/08
# Found workout for Sat 10/04
# Found workout for Tue 09/30
# Found workout for Fri 09/26
# Found workout for Mon 09/22
# Found workout for Thu 09/18
# Found workout for Sun 09/14
# Found workout for Wed 09/10
# Found 10 workouts on page 11
# Total Strength WODs workouts: 120
# Waiting 8.8 seconds before next page...
#
# Processing Strength WODs - Page 12
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=12
# Found workout for Sat 09/06
# Found workout for Tue 09/02
# Found workout for Fri 08/29
# Found workout for Mon 08/25
# Found workout for Thu 08/21
# Found workout for Sun 08/17
# Found workout for Wed 08/13
# Found workout for Sat 08/09
# Found workout for Tue 08/05
# Found workout for Fri 08/01
# Found 10 workouts on page 12
# Total Strength WODs workouts: 130
# Waiting 10.7 seconds before next page...
#
# Processing Strength WODs - Page 13
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=13
# Found workout for Wed 04/04
# Found workout for Sat 03/31
# Found workout for Wed 03/28
# Found workout for Tue 03/27
# Found workout for Fri 03/23
# Found workout for Mon 03/19
# Found workout for Thu 03/15
# Found workout for Sun 03/11
# Found workout for Wed 03/07
# Found workout for Sat 03/03
# Found 10 workouts on page 13
# Total Strength WODs workouts: 140
# Waiting 8.4 seconds before next page...
#
# Processing Strength WODs - Page 14
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=14
# Found workout for Tue 02/28
# Found workout for Fri 02/24
# Found workout for Mon 02/20
# Found workout for Sun 02/12
# Found workout for Wed 02/08
# Found workout for Sat 02/04
# Found workout for Tue 01/31
# Found workout for Sat 01/28
# Found workout for Mon 01/23
# Found workout for Fri 01/20
# Found 10 workouts on page 14
# Total Strength WODs workouts: 150
# Waiting 10.0 seconds before next page...
#
# Processing Strength WODs - Page 15
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=15
# Found workout for Mon 01/16
# Found workout for Thu 01/12
# Found workout for Sun 01/08
# Found workout for Wed 01/04
# Found workout for Sat 12/31
# Found workout for Tue 12/27
# Found workout for Fri 12/23
# Found workout for Mon 12/19
# Found workout for Thu 12/15
# Found workout for Tue 12/13
# Found 10 workouts on page 15
# Total Strength WODs workouts: 160
# Waiting 8.4 seconds before next page...
#
# Processing Strength WODs - Page 16
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=16
# Found workout for Mon 12/12
# Found workout for Thu 12/08
# Found workout for Sat 12/03
# Found workout for Wed 11/30
# Found workout for Tue 11/29
# Found workout for Sat 11/26
# Found workout for Tue 11/22
# Found workout for Mon 11/21
# Found workout for Sat 11/19
# Found workout for Wed 11/16
# Found 10 workouts on page 16
# Total Strength WODs workouts: 170
# Waiting 9.4 seconds before next page...
#
# Processing Strength WODs - Page 17
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Attempt 1 failed: 500 Server Error: Service unavailable (with message) for url: https://web.archive.org/web/20130831060804/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Waiting 6.1 seconds before retry...
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Attempt 2 failed: 500 Server Error: Service unavailable (with message) for url: https://web.archive.org/web/20130831060804/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Waiting 13.9 seconds before retry...
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Attempt 3 failed: 500 Server Error: Service unavailable (with message) for url: https://web.archive.org/web/20130831060804/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Failed to fetch https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=94&sort_by=created&sort_order=DESC&page=17
# Added 170 Strength WODs
# Waiting 19.2 seconds before next category...
#
# Scraping Skill WODs...
# Testing timestamp 20180210001310 for category 95...
# Found working timestamp: 20180210001310
#
# Processing Skill WODs - Page 0
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95
# Found workout for Mon 12/28
# Found workout for Thu 12/24
# Found workout for Sun 12/20
# Found workout for Wed 12/16
# Found workout for Sat 12/12
# Found workout for Tue 12/08
# Found workout for Fri 12/04
# Found workout for Mon 11/30
# Found workout for Thu 11/26
# Found workout for Sun 11/22
# Found 10 workouts on page 0
# Total Skill WODs workouts: 10
# Waiting 8.1 seconds before next page...
#
# Processing Skill WODs - Page 1
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=1
# Found workout for Wed 11/18
# Found workout for Sat 11/14
# Found workout for Tue 11/10
# Found workout for Fri 11/06
# Found workout for Mon 11/02
# Found workout for Thu 10/29
# Found workout for Sun 10/25
# Found workout for Wed 10/21
# Found workout for Sat 10/17
# Found workout for Tue 10/13
# Found 10 workouts on page 1
# Total Skill WODs workouts: 20
# Waiting 11.8 seconds before next page...
#
# Processing Skill WODs - Page 2
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=2
# Found workout for Fri 10/09
# Found workout for Mon 10/05
# Found workout for Thu 10/01
# Found workout for Sun 09/27
# Found workout for Wed 09/23
# Found workout for Sat 09/19
# Found workout for Tue 9/15
# Found workout for Fri 09/11
# Found workout for Mon 09/07
# Found workout for Thu 09/03
# Found 10 workouts on page 2
# Total Skill WODs workouts: 30
# Waiting 11.9 seconds before next page...
#
# Processing Skill WODs - Page 3
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=3
# Found workout for Sun 08/30
# Found workout for Wed 08/26
# Found workout for Sat 08/22
# Found workout for Tue 08/18
# Found workout for Fri 08/14
# Found workout for Mon 08/10
# Found workout for Thu 08/06
# Found workout for Sun 08/02
# Found workout for Wed 07/29
# Found workout for Sat 07/25
# Found 10 workouts on page 3
# Total Skill WODs workouts: 40
# Waiting 10.2 seconds before next page...
#
# Processing Skill WODs - Page 4
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=4
# Found workout for Tue 07/21
# Found workout for Fri 07/17
# Found workout for Mon 07/13
# Found workout for Thu 07/09
# Found workout for Sun 07/05
# Found workout for Wed 07/01
# Found workout for Sat 06/27
# Found workout for Tue 06/23
# Found workout for Fri 06/19
# Found workout for Mon 06/15
# Found 10 workouts on page 4
# Total Skill WODs workouts: 50
# Waiting 11.3 seconds before next page...
#
# Processing Skill WODs - Page 5
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=5
# Found workout for Thu 06/11
# Found workout for Sun 06/07
# Found workout for Wed 06/03
# Found workout for Sat 05/30
# Found workout for Tue 05/26
# Found workout for Fri 05/22
# Found workout for Mon 05/18
# Found workout for Thu 05/14
# Found workout for Sun 05/10
# Found workout for Wed 05/06
# Found 10 workouts on page 5
# Total Skill WODs workouts: 60
# Waiting 11.2 seconds before next page...
#
# Processing Skill WODs - Page 6
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=6
# Found workout for Sat 05/02
# Found workout for Tue 04/28
# Found workout for Fri 04/24
# Found workout for Mon 04/20
# Found workout for Thu 04/16
# Found workout for Sun 04/12
# Found workout for Wed 04/08
# Found workout for Sat 04/04
# Found workout for Tue 03/31
# Found workout for Fri 03/27
# Found 10 workouts on page 6
# Total Skill WODs workouts: 70
# Waiting 10.1 seconds before next page...
#
# Processing Skill WODs - Page 7
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=7
# Found workout for Mon 03/23
# Found workout for Thu 03/19
# Found workout for Sun 03/15
# Found workout for Wed 03/11
# Found workout for Sat 03/07
# Found workout for Tue 03/03
# Found workout for Fri 02/27
# Found workout for Mon 09/23
# Found workout for Thu 02/19
# Found workout for Sun 02/15
# Found 10 workouts on page 7
# Total Skill WODs workouts: 80
# Waiting 11.9 seconds before next page...
#
# Processing Skill WODs - Page 8
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=8
# Found workout for Tue 02/10
# Found workout for Fri 02/06
# Found workout for Mon 02/02
# Found workout for Thu 01/29
# Found workout for Sun 01/25
# Found workout for Wed 01/21
# Found workout for Sat 01/17
# Found workout for Tue 01/13
# Found workout for Fri 01/09
# Found workout for Mon 01/05
# Found 10 workouts on page 8
# Total Skill WODs workouts: 90
# Waiting 12.0 seconds before next page...
#
# Processing Skill WODs - Page 9
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=9
# Found workout for Thu 09/25
# Found workout for Sun 09/21
# Found workout for Wed 09/17
# Found workout for Sat 09/13
# Found workout for Tue 09/09
# Found workout for Fri 09/05
# Found workout for Mon 09/01
# Found workout for Thu 08/28
# Found workout for Sun 08/24
# Found workout for Wed 08/20
# Found 10 workouts on page 9
# Total Skill WODs workouts: 100
# Waiting 10.0 seconds before next page...
#
# Processing Skill WODs - Page 10
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=10
# Found workout for Sat 08/16
# Found workout for Tue 08/12
# Found workout for Fri 08/08
# Found workout for Mon 08/04
# Found workout for Thu 07/31
# Found workout for Sun 07/28
# Found workout for Wed 07/23
# Found workout for Sat 07/19
# Found workout for Tue 07/15
# Found workout for Fri 07/11
# Found 10 workouts on page 10
# Total Skill WODs workouts: 110
# Waiting 12.0 seconds before next page...
#
# Processing Skill WODs - Page 11
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=11
# Found workout for Mon 07/07
# Found workout for Thu 07/03
# Found workout for Sun 06/29
# Found workout for Wed 06/25
# Found workout for Sat 06/21
# Found workout for Tue 06/17
# Found workout for Fri 06/13
# Found workout for Tue 06/10
# Found workout for Fri 06/06
# Found workout for Mon 06/02
# Found 10 workouts on page 11
# Total Skill WODs workouts: 120
# Waiting 8.8 seconds before next page...
#
# Processing Skill WODs - Page 12
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=12
# Found workout for Thu 05/29
# Found workout for Sun 05/25
# Found workout for Wed 05/21
# Found workout for Sat 05/17
# Found workout for Tue 05/13
# Found workout for Fri 05/09
# Found workout for Mon 05/05
# Found workout for Thu 05/01
# Found workout for Sun 04/27
# Found workout for Wed 04/23
# Found 10 workouts on page 12
# Total Skill WODs workouts: 130
# Waiting 10.4 seconds before next page...
#
# Processing Skill WODs - Page 13
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=13
# Found workout for Thu 01/19
# Found workout for Sun 01/15
# Found workout for Wed 01/11
# Found workout for Sat 01/07
# Found workout for Tue 01/03
# Found workout for Fri 12/30
# Found workout for Mon 12/26
# Found workout for Thu 12/22
# Found workout for Sun 12/18
# Found workout for Wed 12/14
# Found 10 workouts on page 13
# Total Skill WODs workouts: 140
# Waiting 10.0 seconds before next page...
#
# Processing Skill WODs - Page 14
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=95&sort_by=created&sort_order=DESC&page=14
# Found workout for Tue 09/27
# Found workout for Thu 09/22
# Found workout for Sun 09/18
# Found workout for Wed 09/14
# Found workout for Sat 09/10
# Found workout for Tue 09/06
# Found workout for Fri 09/02
# Found 7 workouts on page 14
# Total Skill WODs workouts: 147
# No more pages found
# Added 147 Skill WODs
# Waiting 18.8 seconds before next category...
#
# Scraping Flexibility WODs...
# Testing timestamp 20180210001310 for category 96...
# Found working timestamp: 20180210001310
#
# Processing Flexibility WODs - Page 0
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96
# Found workout for Thu 12/31
# Found workout for Sun 12/27
# Found workout for Wed 12/23
# Found workout for Sat 12/19
# Found workout for Tue 12/15
# Found workout for Fri 12/11
# Found workout for Mon 12/07
# Found workout for Thu 12/03
# Found workout for Sun 11/29
# Found workout for Wed 11/25
# Found 10 workouts on page 0
# Total Flexibility WODs workouts: 10
# Waiting 11.4 seconds before next page...
#
# Processing Flexibility WODs - Page 1
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=1
# Found workout for Sat 11/21
# Found workout for Tue 11/17
# Found workout for Fri 11/13
# Found workout for Mon 11/09
# Found workout for Thu 11/05
# Found workout for Sun 11/01
# Found workout for Wed 10/28
# Found workout for Sat 10/24
# Found workout for Tue 10/20
# Found workout for Fri 10/16
# Found 10 workouts on page 1
# Total Flexibility WODs workouts: 20
# Waiting 10.5 seconds before next page...
#
# Processing Flexibility WODs - Page 2
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=2
# Found workout for Mon 10/12
# Found workout for Thu 10/08
# Found workout for Sun 10/04
# Found workout for Wed 09/30
# Found workout for Sat 09/26
# Found workout for Tue 09/22
# Found workout for Fri 09/18
# Found workout for Mon 09/14
# Found workout for Thu 09/10
# Found workout for Sun 09/06
# Found 10 workouts on page 2
# Total Flexibility WODs workouts: 30
# Waiting 8.5 seconds before next page...
#
# Processing Flexibility WODs - Page 3
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=3
# Found workout for Wed 09/02
# Found workout for Sat 08/29
# Found workout for Tue 08/25
# Found workout for Fri 08/21
# Found workout for Mon 08/17
# Found workout for Thu 08/13
# Found workout for Sun 08/09
# Found workout for Wed 08/05
# Found workout for Sat 08/01
# Found workout for Tue 07/28
# Found 10 workouts on page 3
# Total Flexibility WODs workouts: 40
# Waiting 9.8 seconds before next page...
#
# Processing Flexibility WODs - Page 4
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=4
# Found workout for Fri 07/24
# Found workout for Mon 07/20
# Found workout for Thu 07/16
# Found workout for Sun 07/12
# Found workout for Wed 07/08
# Found workout for Sat 07/04
# Found workout for Tue 06/30
# Found workout for Fri 06/26
# Found workout for Mon 06/22
# Found workout for Thu 06/18
# Found 10 workouts on page 4
# Total Flexibility WODs workouts: 50
# Waiting 10.7 seconds before next page...
#
# Processing Flexibility WODs - Page 5
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=5
# Found workout for Sun 06/14
# Found workout for Wed 06/10
# Found workout for Sat 06/06
# Found workout for Tue 06/02
# Found workout for Mon 05/25
# Found workout for Thu 05/21
# Found workout for Sun 05/17
# Found workout for Wed 05/13
# Found workout for Sat 05/09
# Found workout for Tue 05/05
# Found 10 workouts on page 5
# Total Flexibility WODs workouts: 60
# Waiting 10.4 seconds before next page...
#
# Processing Flexibility WODs - Page 6
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=6
# Found workout for Fri 05/01
# Found workout for Mon 04/27
# Found workout for Thu 04/23
# Found workout for Sun 04/19
# Found workout for Wed 04/15
# Found workout for Sat 04/11
# Found workout for Tue 04/07
# Found workout for Fri 04/03
# Found workout for Mon 03/30
# Found workout for Thu 03/26
# Found 10 workouts on page 6
# Total Flexibility WODs workouts: 70
# Waiting 10.5 seconds before next page...
#
# Processing Flexibility WODs - Page 7
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=7
# Found workout for Sun 03/22
# Found workout for Wed 03/18
# Found workout for Sat 03/14
# Found workout for Tue 03/10
# Found workout for Fri 03/06
# Found workout for Mon 03/02
# Found workout for Thu 02/26
# Found workout for Sun 02/22
# Found workout for Wed 02/18
# Found workout for Sat 02/14
# Found 10 workouts on page 7
# Total Flexibility WODs workouts: 80
# Waiting 9.8 seconds before next page...
#
# Processing Flexibility WODs - Page 8
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=8
# Found workout for Mon 02/09
# Found workout for Thu 02/05
# Found workout for Sun 02/01
# Found workout for Wed 01/28
# Found workout for Sat 01/24
# Found workout for Tue 01/20
# Found workout for Fri 01/16
# Found workout for Mon 01/12
# Found workout for Thu 01/08
# Found workout for Sun 01/04
# Found 10 workouts on page 8
# Total Flexibility WODs workouts: 90
# Waiting 11.6 seconds before next page...
#
# Processing Flexibility WODs - Page 9
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=9
# Found workout for Wed 12/31
# Found workout for Sat 12/27
# Found workout for Tue 12/23
# Found workout for Fri 12/19
# Found workout for Mon 12/15
# Found workout for Thu 12/11
# Found workout for Sun 12/07
# Found workout for Wed 12/03
# Found workout for Sat 11/29
# Found workout for Sun 11/23
# Found 10 workouts on page 9
# Total Flexibility WODs workouts: 100
# Waiting 9.1 seconds before next page...
#
# Processing Flexibility WODs - Page 10
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=10
# Found workout for Wed 11/19
# Found workout for Sat 11/15
# Found workout for Tue 11/11
# Found workout for Fri 11/07
# Found workout for Mon 11/03
# Found workout for Thu 10/31
# Found workout for Sun 10/26
# Found workout for Wed 10/22
# Found workout for Sat 10/18
# Found workout for Tue 10/14
# Found 10 workouts on page 10
# Total Flexibility WODs workouts: 110
# Waiting 10.0 seconds before next page...
#
# Processing Flexibility WODs - Page 11
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=11
# Found workout for Fri 10/10
# Found workout for Mon 10/06
# Found workout for Thu 10/02
# Found workout for Sun 09/28
# Found workout for Wed 09/24
# Found workout for Sat 09/20
# Found workout for Tue 09/16
# Found workout for Fri 09/12
# Found workout for Mon 09/08
# Found workout for Thu 09/04
# Found 10 workouts on page 11
# Total Flexibility WODs workouts: 120
# Waiting 9.4 seconds before next page...
#
# Processing Flexibility WODs - Page 12
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=12
# Found workout for Mon 05/12
# Found workout for Thu 05/08
# Found workout for Sun 05/04
# Found workout for Wed 04/30
# Found workout for Sat 04/26
# Found workout for Tue 04/22
# Found workout for Fri 04/18
# Found workout for Mon 04/14
# Found workout for Thu 04/10
# Found workout for Sun 04/06
# Found 10 workouts on page 12
# Total Flexibility WODs workouts: 130
# Waiting 11.9 seconds before next page...
#
# Processing Flexibility WODs - Page 13
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=13
# Found workout for Tue 06/24
# Found workout for Fri 06/20
# Found workout for Mon 06/16
# Found workout for Mon 06/09
# Found workout for Thu 06/05
# Found workout for Sun 06/01
# Found workout for Wed 05/28
# Found workout for Sat 05/24
# Found workout for Tue 05/20
# Found workout for Fri 05/16
# Found 10 workouts on page 13
# Total Flexibility WODs workouts: 140
# Waiting 9.2 seconds before next page...
#
# Processing Flexibility WODs - Page 14
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=14
# Found workout for Mon 05/12
# Found workout for Thu 05/08
# Found workout for Sun 05/04
# Found workout for Wed 04/30
# Found workout for Sat 04/26
# Found workout for Tue 04/22
# Found workout for Fri 04/18
# Found workout for Mon 04/14
# Found workout for Thu 04/10
# Found workout for Sun 04/06
# Found 10 workouts on page 14
# Total Flexibility WODs workouts: 150
# Waiting 11.2 seconds before next page...
#
# Processing Flexibility WODs - Page 15
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=15
# Found workout for Sun 04/06
# Found workout for Wed 04/02
# Found workout for Sat 03/29
# Found workout for Tue 03/25
# Found workout for Fri 03/21
# Found workout for Mon 03/17
# Found workout for Thu 03/13
# Found workout for Sun 03/09
# Found workout for Wed 03/05
# Found workout for Sat 03/01
# Found 10 workouts on page 15
# Total Flexibility WODs workouts: 160
# Waiting 8.0 seconds before next page...
#
# Processing Flexibility WODs - Page 16
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=16
# Found workout for Tue 02/25
# Found workout for Fri 02/21
# Found workout for Mon 02/17
# Found workout for Thu 02/13
# Found workout for Sun 02/09
# Found workout for Wed 02/05
# Found workout for Sat 02/01
# Found workout for Tue 01/28
# Found workout for Fri 01/24
# Found workout for Mon 01/20
# Found 10 workouts on page 16
# Total Flexibility WODs workouts: 170
# Waiting 9.5 seconds before next page...
#
# Processing Flexibility WODs - Page 17
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Attempt 1 failed: 500 Server Error: Service unavailable (with message) for url: https://web.archive.org/web/20130817023431/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Waiting 9.8 seconds before retry...
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Attempt 2 failed: 500 Server Error: Service unavailable (with message) for url: https://web.archive.org/web/20130817023431/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Waiting 13.5 seconds before retry...
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Attempt 3 failed: 500 Server Error: Service unavailable (with message) for url: https://web.archive.org/web/20130817023431/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Failed to fetch https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=96&sort_by=created&sort_order=DESC&page=17
# Added 170 Flexibility WODs
# Waiting 15.2 seconds before next category...
#
# Scraping MetCon WODs...
# Testing timestamp 20180210001310 for category 97...
# Found working timestamp: 20180210001310
#
# Processing MetCon WODs - Page 0
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97
# Found workout for Wed 12/30
# Found workout for Sat 12/26
# Found workout for Tue 12/22
# Found workout for Fri 12/18
# Found workout for Mon 12/14
# Found workout for Thu 12/10
# Found workout for Sun 12/06
# Found workout for Wed 12/02
# Found workout for Sat 11/28
# Found workout for Tue 11/24
# Found 10 workouts on page 0
# Total MetCon WODs workouts: 10
# Waiting 10.8 seconds before next page...
#
# Processing MetCon WODs - Page 1
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=1
# Found workout for Fri 11/20
# Found workout for Mon 11/16
# Found workout for Thu 11/12
# Found workout for Sun 11/08
# Found workout for Wed 11/04
# Found workout for Sat 10/31
# Found workout for Tue 10/27
# Found workout for Fri 10/23
# Found workout for Mon 10/19
# Found workout for Thu 10/15
# Found 10 workouts on page 1
# Total MetCon WODs workouts: 20
# Waiting 11.5 seconds before next page...
#
# Processing MetCon WODs - Page 2
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=2
# Found workout for Sun 10/11
# Found workout for Sat 10/03
# Found workout for Tue 09/29
# Found workout for Fri 09/25
# Found workout for Mon 09/21
# Found workout for Thu 09/17
# Found workout for Sun 09/13
# Found workout for Wed 09/09
# Found workout for Sat 09/05
# Found 9 workouts on page 2
# Total MetCon WODs workouts: 29
# Waiting 11.9 seconds before next page...
#
# Processing MetCon WODs - Page 3
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=3
# Found workout for Tue 09/01
# Found workout for Fri 08/28
# Found workout for Mon 08/24
# Found workout for Thu 08/20
# Found workout for Sun 08/16
# Found workout for Wed 08/12
# Found workout for Sat 08/08
# Found workout for Tue 08/04
# Found workout for Fri 07/31
# Found workout for Mon 07/27
# Found 10 workouts on page 3
# Total MetCon WODs workouts: 39
# Waiting 11.7 seconds before next page...
#
# Processing MetCon WODs - Page 4
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=4
# Found workout for Thu 07/23
# Found workout for Sun 07/19
# Found workout for Wed 07/15
# Found workout for Sat 07/11
# Found workout for Tue 07/07
# Found workout for Fri 07/03
# Found workout for Mon 06/29
# Found workout for Thu 06/25
# Found workout for Sun 06/21
# Found workout for Wed 06/17
# Found 10 workouts on page 4
# Total MetCon WODs workouts: 49
# Waiting 10.0 seconds before next page...
#
# Processing MetCon WODs - Page 5
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=5
# Found workout for Sat 06/13
# Found workout for Tue 06/09
# Found workout for Fri 06/05
# Found workout for Mon 06/01
# Found workout for Thu 05/28
# Found workout for Sun 05/24
# Found workout for Wed 05/20
# Found workout for Sat 05/16
# Found workout for Tue 05/12
# Found workout for Fri 05/08
# Found 10 workouts on page 5
# Total MetCon WODs workouts: 59
# Waiting 11.5 seconds before next page...
#
# Processing MetCon WODs - Page 6
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=6
# Found workout for Mon 05/04
# Found workout for Thu 04/30
# Found workout for Sun 04/26
# Found workout for Wed 04/22
# Found workout for Sat 04/18
# Found workout for Tue 04/14
# Found workout for Fri 04/10
# Found workout for Mon 04/06
# Found workout for Thu 04/02
# Found workout for Sun 03/29
# Found 10 workouts on page 6
# Total MetCon WODs workouts: 69
# Waiting 9.5 seconds before next page...
#
# Processing MetCon WODs - Page 7
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=7
# Found workout for Wed 03/25
# Found workout for Sat 03/21
# Found workout for Tue 03/17
# Found workout for Fri 03/13
# Found workout for Mon 03/09
# Found workout for Thu 03/05
# Found workout for Sun 03/01
# Found workout for Wed 02/25
# Found workout for Sat 02/21
# Found workout for Tue 02/17
# Found 10 workouts on page 7
# Total MetCon WODs workouts: 79
# Waiting 9.9 seconds before next page...
#
# Processing MetCon WODs - Page 8
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=8
# Found workout for Fri 02/13
# Found workout for Thu 02/12
# Found workout for Sun 02/08
# Found workout for Wed 02/04
# Found workout for Sat 01/31
# Found workout for Tue 01/27
# Found workout for Fri 01/23
# Found workout for Mon 01/19
# Found workout for Thu 01/15
# Found workout for Sun 01/11
# Found 10 workouts on page 8
# Total MetCon WODs workouts: 89
# Waiting 11.0 seconds before next page...
#
# Processing MetCon WODs - Page 9
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=9
# Found workout for Fri 09/19
# Found workout for Mon 09/15
# Found workout for Thu 09/11
# Found workout for Sun 09/07
# Found workout for Wed 09/03
# Found workout for Sat 08/30
# Found workout for Tue 08/26
# Found workout for Fri 08/22
# Found workout for Mon 08/18
# Found workout for Thu 08/14
# Found 10 workouts on page 9
# Total MetCon WODs workouts: 99
# Waiting 9.2 seconds before next page...
#
# Processing MetCon WODs - Page 10
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=10
# Found workout for Sun 08/10
# Found workout for Wed 08/06
# Found workout for Sat 08/02
# Found workout for Tue 07/29
# Found workout for Fri 07/25
# Found workout for Mon 07/21
# Found workout for Thu 07/17
# Found workout for Sun 07/13
# Found workout for Wed 07/09
# Found workout for Sat 07/05
# Found 10 workouts on page 10
# Total MetCon WODs workouts: 109
# Waiting 11.2 seconds before next page...
#
# Processing MetCon WODs - Page 11
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=11
# Found workout for Tue 07/01
# Found workout for Fri 06/27
# Found workout for Mon 06/23
# Found workout for Thu 06/19
# Found workout for Sun 06/15
# Found workout for Thu 06/12
# Found workout for Sun 06/08
# Found workout for Wed 06/04
# Found workout for Sat 05/31
# Found workout for Tue 05/27
# Found 10 workouts on page 11
# Total MetCon WODs workouts: 119
# Waiting 8.8 seconds before next page...
#
# Processing MetCon WODs - Page 12
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=12
# Found workout for Fri 05/23
# Found workout for Mon 05/19
# Found workout for Thu 05/15
# Found workout for Sun 05/11
# Found workout for Wed 05/07
# Found workout for Sat 05/03
# Found workout for Tue 04/29
# Found workout for Fri 04/25
# Found workout for Mon 04/21
# Found workout for Thu 04/17
# Found 10 workouts on page 12
# Total MetCon WODs workouts: 129
# Waiting 8.1 seconds before next page...
#
# Processing MetCon WODs - Page 13
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Attempt 1 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Waiting 8.8 seconds before retry...
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Attempt 2 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Waiting 12.5 seconds before retry...
# Fetching: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Attempt 3 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Failed to fetch https://web.archive.org/web/20180210001310/http://gymnasticswod.com/wod?field_focus_tid=97&sort_by=created&sort_order=DESC&page=13
# Added 129 MetCon WODs
# Waiting 18.1 seconds before next category...
#
# Saved 616 workouts to workouts.csv
#
# Workouts by category:
# category
# Strength WODs       170
# Flexibility WODs    170
# Skill WODs          147
# MetCon WODs         129
# Name: count, dtype: int64
#
# Workout types:
# workout_type
#                314
# FOR QUALITY    161
# ROUNDS          72
# FOR TIME        50
# AMRAP           19
# Name: count, dtype: int64

# %% [markdown]
# Check the quality of the data produced by the scraping script

# %%
import os
import pandas as pd

# First, let's check if the file exists in the current directory
print("Checking current directory...")
print(f"Current working directory: {os.getcwd()}")
print("\nFiles in current directory:")
for file in os.listdir():
    if file.endswith('.csv'):
        print(f"Found CSV: {file} (Size: {os.path.getsize(file)} bytes)")

        # If we find workouts.csv, let's look at its contents
        if file == 'workouts.csv':
            df = pd.read_csv(file)
            print(f"\nWorkouts.csv contains {len(df)} rows")
            print("\nColumns:", df.columns.tolist())
            print("\nFirst few rows:")
            print(df.head())

            # Show distribution of workout categories
            print("\nWorkouts by category:")
            print(df['category'].value_counts())
# Out:
# Checking current directory...
# Current working directory: /content
#
# Files in current directory:
# Found CSV: workouts.csv (Size: 126414 bytes)
#
# Workouts.csv contains 616 rows
#
# Columns: ['date', 'category', 'workout_type', 'workout']
#
# First few rows:
#         date       category workout_type  \
# 0  Tue 12/29  Strength WODs  FOR QUALITY
# 1  Fri 12/25  Strength WODs  FOR QUALITY
# 2  Mon 12/21  Strength WODs  FOR QUALITY
# 3  Thu 12/17  Strength WODs  FOR QUALITY
# 4  Sun 12/13  Strength WODs  FOR QUALITY
#
#                                              workout
# 0  FOR QUALITY: 20 Meter Handstand Walk Laterals ...
# 1  For QUALITYPerform In Any Order:30 Pull Up in ...
# 2  For QUALITY3 ROUNDS: 6 V Outs  6  Ring Straigh...
# 3  FOR QUALITY: Accumulate 100 Meter Handstand Walks
# 4  For QUALITY3 ROUNDS: 20  Back Leg Swings  Left...
#
# Workouts by category:
# category
# Strength WODs       170
# Flexibility WODs    170
# Skill WODs          147
# MetCon WODs         129
# Name: count, dtype: int64
# Found CSV: test_workouts.csv (Size: 1564 bytes)

# %%
## more code to view the results and see wether everything is as expected before moving to G Sheets
import pandas as pd

def check_data():
    print("Reading workouts.csv...")
    df = pd.read_csv('workouts.csv')

    print(f"\nTotal workouts: {len(df)}")

    print("\nWorkouts by category:")
    print(df['category'].value_counts())

    print("\nWorkout types:")
    print(df['workout_type'].value_counts())

    print("\nDate range:")
    print(f"Earliest: {df['date'].min()}")
    print(f"Latest: {df['date'].max()}")

    print("\nSample workout from each category:")
    for category in df['category'].unique():
        sample = df[df['category'] == category].iloc[0]
        print(f"\n{category}:")
        print(f"Date: {sample['date']}")
        print(f"Type: {sample['workout_type']}")
        print("Workout preview:")
        print(sample['workout'][:200], "...")

check_data()
# Out:
# Reading workouts.csv...
#
# Total workouts: 616
#
# Workouts by category:
# category
# Strength WODs       170
# Flexibility WODs    170
# Skill WODs          147
# MetCon WODs         129
# Name: count, dtype: int64
#
# Workout types:
# workout_type
# FOR QUALITY    161
# ROUNDS          72
# FOR TIME        50
# AMRAP           19
# Name: count, dtype: int64
#
# Date range:
# Earliest: Fri 01/02
# Latest: Wed 12/31
#
# Sample workout from each category:
#
# Strength WODs:
# Date: Tue 12/29
# Type: FOR QUALITY
# Workout preview:
# FOR QUALITY: 20 Meter Handstand Walk Laterals  Accumulate 3 Minutes Of L Seats  Accumulate 3 Minutes Of Supermans  Accumulate 3 Minutes Of L Hangs ...
#
# Skill WODs:
# Date: Mon 12/28
# Type: nan
# Workout preview:
# PRACTICE for 10 minutes:Roll to Handstand Push Up Progression Pt.1  Roll to Handstand Push Up Progression Pt.2  Roll to Handstand Push Up Progression Pt.3 ...
#
# Flexibility WODs:
# Date: Thu 12/31
# Type: nan
# Workout preview:
# FLEXIBILITY:Happy New Year! Accumulate 5 Minutes Of   Bridge Ups  Hold, Every Time You Break, Perform 5 Skin the Cats ...
#
# MetCon WODs:
# Date: Wed 12/30
# Type: FOR TIME
# Workout preview:
# FOR TIME: 50 Handstand Push Ups with Wall and Kip  Every Time You Break Perform 5 V Ups ...

# %% [markdown]
# code to run to get into G sheets

# %%
## code used to get the workouts.csv reformatted and inserted into G SHeets
def upload_to_sheets():
    print("Setting up Google Sheets access...")
    drive.mount('/content/drive', force_remount=True)

    auth.authenticate_user()
    creds, _ = default()
    gc = gspread.authorize(creds)

    print("Reading and cleaning workout data...")
    df = pd.read_csv('workouts.csv')

    # Clean NaN values
    df['workout_type'] = df['workout_type'].fillna('Unspecified')
    df['workout'] = df['workout'].fillna('')

    print("\nCreating main spreadsheet...")
    workbook = gc.create('Gymnastics WODs Database')

    print("Creating Overview sheet...")
    overview = workbook.sheet1
    overview.update_title('Overview')

    overview_data = [
        ['Gymnastics WODs Database'],
        [''],
        ['Total Workouts:', str(len(df))],
        ['Date Range:', f"{df['date'].min()} to {df['date'].max()}"],
        [''],
        ['Workouts by Category'],
        ['Category', 'Count']
    ]

    category_counts = df['category'].value_counts()
    for category, count in category_counts.items():
        overview_data.append([category, str(count)])

    overview_data.extend([
        [''],
        ['Workout Types Distribution'],
        ['Type', 'Count']
    ])

    type_counts = df['workout_type'].value_counts()
    for wtype, count in type_counts.items():
        overview_data.append([wtype, str(count)])

    print("Updating Overview sheet...")
    overview.update('A1', overview_data)

    print("\nCreating All Workouts sheet...")
    all_workouts = workbook.add_worksheet(title='All Workouts', rows=len(df)+1, cols=4)

    # Prepare headers and data
    headers = ['Date', 'Category', 'Type', 'Workout']

    # Convert DataFrame to list of lists
    all_data = [headers]
    all_data.extend(df[['date', 'category', 'workout_type', 'workout']].fillna('').values.tolist())

    print(f"Uploading data to All Workouts sheet...")
    all_workouts.update('A1', all_data)

    # Create category sheets
    for category in df['category'].unique():
        print(f"\nCreating sheet for {category}...")
        category_df = df[df['category'] == category]

        sheet_name = category.replace(' ', '_')
        category_sheet = workbook.add_worksheet(title=sheet_name, rows=len(category_df)+1, cols=3)

        # Prepare category data
        category_data = [['Date', 'Type', 'Workout']]
        category_data.extend(category_df[['date', 'workout_type', 'workout']].fillna('').values.tolist())

        print(f"Uploading data to {category} sheet...")
        category_sheet.update('A1', category_data)

    print("\nSpreadsheet creation complete!")
    print(f"Spreadsheet URL: {workbook.url}")

    # Share the spreadsheet
    workbook.share(None, perm_type='anyone', role='reader')

    return workbook.url

try:
    print("Starting Google Sheets upload...")
    spreadsheet_url = upload_to_sheets()
    print(f"\nYour spreadsheet is available at: {spreadsheet_url}")

except Exception as e:
    print(f"An error occurred: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# Starting Google Sheets upload...
# Setting up Google Sheets access...
# Mounted at /content/drive
# Reading and cleaning workout data...
#
# Creating main spreadsheet...
# Creating Overview sheet...
# Updating Overview sheet...
# <ipython-input-31-9f8b8c9b7f74>:48: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   overview.update('A1', overview_data)
# Creating All Workouts sheet...
# Uploading data to All Workouts sheet...
# <ipython-input-31-9f8b8c9b7f74>:61: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   all_workouts.update('A1', all_data)
# Creating sheet for Strength WODs...
# Uploading data to Strength WODs sheet...
# <ipython-input-31-9f8b8c9b7f74>:76: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   category_sheet.update('A1', category_data)
# Creating sheet for Skill WODs...
# Uploading data to Skill WODs sheet...
# <ipython-input-31-9f8b8c9b7f74>:76: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   category_sheet.update('A1', category_data)
# Creating sheet for Flexibility WODs...
# Uploading data to Flexibility WODs sheet...
# <ipython-input-31-9f8b8c9b7f74>:76: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   category_sheet.update('A1', category_data)
# Creating sheet for MetCon WODs...
# Uploading data to MetCon WODs sheet...
# <ipython-input-31-9f8b8c9b7f74>:76: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   category_sheet.update('A1', category_data)
# Spreadsheet creation complete!
# Spreadsheet URL: https://docs.google.com/spreadsheets/d/1uQPeoOtOE5Yt3iKXuWyGQwnfCEo6h74LXYoUxuKnt5w
#
# Your spreadsheet is available at: https://docs.google.com/spreadsheets/d/1uQPeoOtOE5Yt3iKXuWyGQwnfCEo6h74LXYoUxuKnt5w

# %% [markdown]
# # Movements

# %%
# first set of scripts was for the workouts - this script is for the exercise instructions and corresponding videos
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
from urllib.parse import urljoin

class MovementScraper:
    def __init__(self):
        self.wayback_base = "https://web.archive.org"
        self.base_url = f"{self.wayback_base}/web/20180204210343/http://gymnasticswod.com/library"
        self.movements = []
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }

    def get_page_content(self, url, retry_count=3):
        """Get page content with error handling"""
        # Ensure we have a full URL
        if not url.startswith('http'):
            url = urljoin(self.wayback_base, url)

        for attempt in range(retry_count):
            try:
                print(f"Fetching: {url}")
                response = requests.get(url, headers=self.headers, timeout=15)
                response.raise_for_status()
                if response.status_code == 200:
                    return response.text
            except requests.RequestException as e:
                print(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt + 1 == retry_count:
                    print(f"Failed to fetch {url}")
                    return None
                delay = (2 ** attempt) * 5 + random.uniform(1, 5)
                print(f"Waiting {delay:.1f} seconds before retry...")
                time.sleep(delay)
        return None

    def extract_video_source(self, movement_url):
        """Extract video source from movement page"""
        content = self.get_page_content(movement_url)
        if not content:
            return None

        soup = BeautifulSoup(content, 'html.parser')
        video_iframe = soup.find('iframe')
        if video_iframe and 'src' in video_iframe.attrs:
            return video_iframe['src']
        return None

    def parse_metadata(self, metadata_text):
        """Parse category, apparatus, and movement from metadata string"""
        metadata = {
            'category': '',
            'apparatus': '',
            'movement_type': ''
        }

        if not metadata_text:
            return metadata

        try:
            parts = metadata_text.split('|')
            for part in parts:
                part = part.strip()
                if 'Category:' in part:
                    metadata['category'] = part.split('Category:')[1].strip()
                elif 'Apparatus:' in part:
                    metadata['apparatus'] = part.split('Apparatus:')[1].strip()
                elif 'Movement:' in part:
                    metadata['movement_type'] = part.split('Movement:')[1].strip()
        except Exception as e:
            print(f"Error parsing metadata: {str(e)}")
            print(f"Metadata text: {metadata_text}")

        return metadata

    def parse_movement(self, movement_row):
        """Parse individual movement information"""
        try:
            # Find the movement title
            title = movement_row.find('a')
            if not title:
                print("No title link found")
                return None

            movement_title = title.text.strip()
            movement_url = title['href']
            print(f"Found movement: {movement_title}")
            print(f"URL: {movement_url}")

            # Extract instructions
            instructions = []
            instruction_list = movement_row.find('ul')
            if instruction_list:
                instructions = [li.text.strip() for li in instruction_list.find_all('li')]

            # Get metadata
            metadata_div = movement_row.find(lambda tag: tag.name == 'div' and
                                          tag.text and
                                          ('Category:' in tag.text or
                                           'Apparatus:' in tag.text or
                                           'Movement:' in tag.text))
            metadata = self.parse_metadata(metadata_div.text if metadata_div else '')

            # Get video source
            video_src = self.extract_video_source(movement_url)

            movement_data = {
                'title': movement_title,
                'instructions': '\n'.join(instructions),
                'movement_url': movement_url,
                'video_src': video_src,
                'category': metadata['category'],
                'apparatus': metadata['apparatus'],
                'movement_type': metadata['movement_type']
            }

            print(f"Successfully parsed movement: {movement_title}")
            return movement_data

        except Exception as e:
            print(f"Error parsing movement: {str(e)}")
            return None

    def scrape_movements(self, max_pages=None):
        """Scrape all movements from the library"""
        page = 0

        while True:
            if max_pages is not None and page >= max_pages:
                print(f"Reached maximum number of pages ({max_pages})")
                break

            url = self.base_url
            if page > 0:
                url += f"?page={page}"

            print(f"\nProcessing page {page}")
            content = self.get_page_content(url)

            if not content:
                break

            soup = BeautifulSoup(content, 'html.parser')

            # Find the view-content container
            view_content = soup.find('div', class_='view-content')
            if not view_content:
                print("No view-content container found")
                break

            # Find all movement rows
            movement_rows = view_content.find_all('li', class_=lambda x: x and 'views-row' in x)

            print(f"\nFound {len(movement_rows)} potential movement rows")

            if not movement_rows:
                print("No movements found on this page")
                break

            movements_added = 0
            for row in movement_rows:
                movement_data = self.parse_movement(row)
                if movement_data:
                    self.movements.append(movement_data)
                    movements_added += 1

            print(f"Added {movements_added} movements from page {page}")
            print(f"Total movements scraped: {len(self.movements)}")

            # Check for next page
            next_page = soup.find('a', string='next ›')
            if not next_page:
                print("No more pages found")
                break

            page += 1
            delay = random.uniform(8, 12)
            print(f"Waiting {delay:.1f} seconds before next page...")
            time.sleep(delay)

    def save_to_csv(self, filename='movements.csv'):
        """Save movements to CSV file"""
        if not self.movements:
            print("No movements to save!")
            return

        df = pd.DataFrame(self.movements)
        df.to_csv(filename, index=False)
        print(f"\nSaved {len(self.movements)} movements to {filename}")

        if 'category' in df.columns:
            print("\nMovements by category:")
            print(df['category'].value_counts())

        if 'apparatus' in df.columns:
            print("\nMovements by apparatus:")
            print(df['apparatus'].value_counts())

def main():
    scraper = MovementScraper()
    try:
        print("Starting movement library scrape...")
        # Start with just 2 pages for testing
        scraper.scrape_movements(max_pages=2)
        scraper.save_to_csv()

    except KeyboardInterrupt:
        print("\nScraping interrupted by user!")
        if scraper.movements:
            scraper.save_to_csv('movements_partial.csv')
            print("Partial results saved!")
    except Exception as e:
        print(f"\nAn error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        if scraper.movements:
            scraper.save_to_csv('movements_error.csv')
            print("Partial results saved due to error!")

if __name__ == "__main__":
    main()
# Out:
# Starting movement library scrape...
#
# Processing page 0
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/library
#
# Found 10 potential movement rows
# Found movement: Back Leg Swing
# URL: /web/20180204210343/http://gymnasticswod.com/content/back-leg-swing
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/back-leg-swing
# Successfully parsed movement: Back Leg Swing
# Found movement: Back Lever
# URL: /web/20180204210343/http://gymnasticswod.com/content/back-lever
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/back-lever
# Successfully parsed movement: Back Lever
# Found movement: Back Tuck
# URL: /web/20180204210343/http://gymnasticswod.com/content/back-tuck
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/back-tuck
# Successfully parsed movement: Back Tuck
# Found movement: Back Uprise from Dip Swing
# URL: /web/20180204210343/http://gymnasticswod.com/content/back-uprise
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/back-uprise
# Successfully parsed movement: Back Uprise from Dip Swing
# Found movement: Back Uprise to Handstand from Dip Swing
# URL: /web/20180204210343/http://gymnasticswod.com/content/back-uprise-handstand
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/back-uprise-handstand
# Successfully parsed movement: Back Uprise to Handstand from Dip Swing
# Found movement: Backward Roll
# URL: /web/20180204210343/http://gymnasticswod.com/content/backward-roll-floor
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/backward-roll-floor
# Successfully parsed movement: Backward Roll
# Found movement: Backward Roll
# URL: /web/20180204210343/http://gymnasticswod.com/content/backward-roll
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/backward-roll
# Successfully parsed movement: Backward Roll
# Found movement: Bar Muscle Up
# URL: /web/20180204210343/http://gymnasticswod.com/content/muscle-bar
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/muscle-bar
# Successfully parsed movement: Bar Muscle Up
# Found movement: Bar Pull Up
# URL: /web/20180204210343/http://gymnasticswod.com/content/pull-bar
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/pull-bar
# Successfully parsed movement: Bar Pull Up
# Found movement: Bent Arm Back Extension Roll
# URL: /web/20180204210343/http://gymnasticswod.com/content/bent-arm-back-extension-roll
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/content/bent-arm-back-extension-roll
# Successfully parsed movement: Bent Arm Back Extension Roll
# Added 10 movements from page 0
# Total movements scraped: 10
# Waiting 8.8 seconds before next page...
#
# Processing page 1
# Fetching: https://web.archive.org/web/20180204210343/http://gymnasticswod.com/library?page=1
#
# Found 10 potential movement rows
# Found movement: Bent Arm Back Extension Roll to Push Up Position
# URL: /web/20111013223505/http://gymnasticswod.com/content/bent-arm-back-extension-roll-push-position
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/bent-arm-back-extension-roll-push-position
# Successfully parsed movement: Bent Arm Back Extension Roll to Push Up Position
# Found movement: Box Jump
# URL: /web/20111013223505/http://gymnasticswod.com/content/box-jump
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/box-jump
# Successfully parsed movement: Box Jump
# Found movement: Bridge Up
# URL: /web/20111013223505/http://gymnasticswod.com/content/bridge
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/bridge
# Successfully parsed movement: Bridge Up
# Found movement: Broad Jump
# URL: /web/20111013223505/http://gymnasticswod.com/content/broad-jump
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/broad-jump
# Successfully parsed movement: Broad Jump
# Found movement: Bulgarian Dip
# URL: /web/20111013223505/http://gymnasticswod.com/content/bulgarian-dip
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/bulgarian-dip
# Successfully parsed movement: Bulgarian Dip
# Found movement: Burpee
# URL: /web/20111013223505/http://gymnasticswod.com/content/burpee
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/burpee
# Successfully parsed movement: Burpee
# Found movement: Burpee Box Jump
# URL: /web/20111013223505/http://gymnasticswod.com/content/burpee-box-jump
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/burpee-box-jump
# Successfully parsed movement: Burpee Box Jump
# Found movement: Butterfly Pull Up
# URL: /web/20111013223505/http://gymnasticswod.com/content/butterfly-pull
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/butterfly-pull
# Successfully parsed movement: Butterfly Pull Up
# Found movement: Candle Stick to Lever
# URL: /web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever
# Attempt 1 failed: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x79ac55f78730>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Waiting 7.3 seconds before retry...
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever
# Attempt 2 failed: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x79ac55f78ca0>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Waiting 11.4 seconds before retry...
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever
# Attempt 3 failed: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x79ac55f79630>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Failed to fetch https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever
# Successfully parsed movement: Candle Stick to Lever
# Found movement: Cartwheel
# URL: /web/20111013223505/http://gymnasticswod.com/content/cartwheel
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/cartwheel
# Attempt 1 failed: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20111013223505/http://gymnasticswod.com/content/cartwheel (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x79ac55f7a260>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Waiting 8.4 seconds before retry...
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/cartwheel
# Attempt 2 failed: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20111013223505/http://gymnasticswod.com/content/cartwheel (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x79ac55f7a800>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Waiting 13.8 seconds before retry...
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/cartwheel
# Attempt 3 failed: HTTPSConnectionPool(host='web.archive.org', port=443): Max retries exceeded with url: /web/20111013223505/http://gymnasticswod.com/content/cartwheel (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x79ac55f79f30>: Failed to establish a new connection: [Errno 111] Connection refused'))
# Failed to fetch https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/cartwheel
# Successfully parsed movement: Cartwheel
# Added 10 movements from page 1
# Total movements scraped: 20
# Waiting 10.5 seconds before next page...
# Reached maximum number of pages (2)
#
# Saved 20 movements to movements.csv
#
# Movements by category:
# category
# Functional         11
# Skill               6
# Strength            2
# FunctionalSkill     1
# Name: count, dtype: int64
#
# Movements by apparatus:
# apparatus
# Floor       10
# Rings        3
# High Bar     3
# P-Bars       2
# Box          2
# Name: count, dtype: int64

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import json
from urllib.parse import urljoin

class MovementScraper:
    def __init__(self):
        self.wayback_base = "https://web.archive.org"
        self.base_url = f"{self.wayback_base}/web/20180202184709/http://gymnasticswod.com/library"
        self.movements = []
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Connection': 'keep-alive'
        }
        self.session = requests.Session()
        self.last_request_time = 0
        self.min_request_delay = 15  # Increased base delay

    def wait_between_requests(self):
        """Ensure minimum delay between requests with some randomization"""
        elapsed = time.time() - self.last_request_time
        if elapsed < self.min_request_delay:
            wait_time = self.min_request_delay - elapsed + random.uniform(1, 5)
            time.sleep(wait_time)
        self.last_request_time = time.time()

    def get_page_content(self, url, retry_count=5, initial_delay=30):
        """Get page content with improved error handling and rate limiting"""
        if not url.startswith('http'):
            url = urljoin(self.wayback_base, url)

        for attempt in range(retry_count):
            try:
                self.wait_between_requests()
                print(f"Fetching: {url}")
                response = self.session.get(url, headers=self.headers, timeout=30)

                if response.status_code == 429:  # Too Many Requests
                    delay = initial_delay * (attempt + 1)  # Increase delay with each attempt
                    print(f"Rate limited. Waiting {delay} seconds...")
                    time.sleep(delay)
                    continue

                response.raise_for_status()
                if response.status_code == 200:
                    return response.text

            except requests.RequestException as e:
                print(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt + 1 == retry_count:
                    print(f"Failed to fetch {url}")
                    return None

                delay = initial_delay * (2 ** attempt)  # Exponential backoff
                print(f"Waiting {delay:.1f} seconds before retry...")
                time.sleep(delay)

        return None

    def extract_video_source(self, movement_url):
        """Extract video source from movement detail page"""
        content = self.get_page_content(movement_url)
        if not content:
            return ''

        soup = BeautifulSoup(content, 'html.parser')

        # Find all iframes
        iframes = soup.find_all('iframe')
        print(f"Found {len(iframes)} iframes")

        for iframe in iframes:
            src = iframe.get('src', '')
            if not src or 'donate' in src:  # Skip donation iframe
                continue

            # Make sure we have a full URL
            if not src.startswith('http'):
                src = urljoin(self.wayback_base, src)

            # First try to get small size, then medium if small isn't available
            if 'size=small' in src:
                print(f"Found small video source: {src}")
                return src
            elif 'size=medium' in src:
                print(f"Found medium video source: {src}")
                return src

        return ''

    def parse_metadata(self, metadata_text):
        """Parse category, apparatus, and movement from metadata string"""
        metadata = {
            'category': '',
            'apparatus': '',
            'movement_type': ''
        }

        if not metadata_text:
            return metadata

        try:
            parts = metadata_text.split('|')
            for part in parts:
                part = part.strip()
                if 'Category:' in part:
                    metadata['category'] = part.split('Category:')[1].strip()
                elif 'Apparatus:' in part:
                    metadata['apparatus'] = part.split('Apparatus:')[1].strip()
                elif 'Movement:' in part:
                    metadata['movement_type'] = part.split('Movement:')[1].strip()
        except Exception as e:
            print(f"Error parsing metadata: {str(e)}")

        return metadata

    def parse_movement(self, movement_row):
        """Parse individual movement information"""
        try:
            # Find the movement title
            title = movement_row.find('a')
            if not title:
                return None

            movement_title = title.text.strip()
            movement_url = title['href']
            print(f"\nFound movement: {movement_title}")

            # Extract instructions
            instructions = []
            instruction_list = movement_row.find('ul')
            if instruction_list:
                instructions = [li.text.strip() for li in instruction_list.find_all('li')]
            else:
                # Check for text in field-item
                field_item = movement_row.find('div', class_='field-item')
                if field_item:
                    text = field_item.get_text(strip=True)
                    if text:
                        instructions = [text]

            # Get metadata
            metadata_div = movement_row.find(lambda tag: tag.name == 'div' and
                                          tag.text and
                                          ('Category:' in tag.text or
                                           'Apparatus:' in tag.text or
                                           'Movement:' in tag.text))

            metadata = self.parse_metadata(metadata_div.text if metadata_div else '')

            # Get video source
            full_url = urljoin(self.wayback_base, movement_url)
            video_src = self.extract_video_source(full_url)

            movement_data = {
                'title': movement_title,
                'instructions': '\n'.join(instructions),
                'movement_url': movement_url,
                'category': metadata['category'],
                'apparatus': metadata['apparatus'],
                'movement_type': metadata['movement_type'],
                'video_src': video_src
            }

            print(f"Successfully parsed movement: {movement_title}")
            return movement_data

        except Exception as e:
            print(f"Error parsing movement: {str(e)}")
            return None

    def scrape_movements(self, max_pages=None, start_page=0):
        """Scrape all movements with improved error handling"""
        page = start_page
        empty_page_count = 0
        consecutive_error_count = 0

        while True:
            if max_pages is not None and page >= start_page + max_pages:
                print(f"Reached maximum number of pages ({max_pages})")
                break

            url = self.base_url
            if page > 0:
                url += f"?page={page}"

            print(f"\nProcessing page {page}")
            content = self.get_page_content(url)

            if not content:
                consecutive_error_count += 1
                if consecutive_error_count >= 3:
                    print("Too many consecutive errors, stopping scrape")
                    break
                page += 1
                continue
            else:
                consecutive_error_count = 0

            soup = BeautifulSoup(content, 'html.parser')

            # Find all movement rows
            movement_rows = soup.find_all('li', class_=lambda x: x and 'views-row' in x)

            print(f"\nFound {len(movement_rows)} potential movement rows")

            if not movement_rows:
                empty_page_count += 1
                print(f"No movements found on page {page} (Empty page count: {empty_page_count})")
                if empty_page_count >= 3:
                    print("Found 3 consecutive empty pages, ending scrape")
                    break
                page += 1
                continue
            else:
                empty_page_count = 0

            movements_added = 0
            for row in movement_rows:
                movement_data = self.parse_movement(row)
                if movement_data:
                    self.movements.append(movement_data)
                    movements_added += 1
                    self.save_progress()

            print(f"Added {movements_added} movements from page {page}")
            print(f"Total movements scraped: {len(self.movements)}")

            page += 1
            delay = random.uniform(15, 20)  # Increased delay between pages
            print(f"Waiting {delay:.1f} seconds before next page...")
            time.sleep(delay)

    def save_progress(self, filename='movements_progress.json'):
        """Save progress to file"""
        with open(filename, 'w') as f:
            json.dump(self.movements, f)
        print(f"Progress saved to {filename}")

    def load_progress(self, filename='movements_progress.json'):
        """Load progress from file"""
        try:
            with open(filename, 'r') as f:
                self.movements = json.load(f)
            print(f"Loaded {len(self.movements)} movements from {filename}")
        except FileNotFoundError:
            print("No progress file found, starting fresh")

    def save_to_csv(self, filename='movements.csv'):
        """Save movements to CSV file"""
        if not self.movements:
            print("No movements to save!")
            return

        df = pd.DataFrame(self.movements)
        df.to_csv(filename, index=False)
        print(f"\nSaved {len(self.movements)} movements to {filename}")

        # Print statistics
        for column in df.columns:
            non_empty = df[column].notna().sum()
            print(f"{column}: {non_empty}/{len(df)} rows have data ({(non_empty/len(df)*100):.1f}%)")

def main():
    scraper = MovementScraper()
    try:
        print("Starting movement library scrape...")
        # Starting fresh - not loading previous progress
        scraper.scrape_movements()
        scraper.save_to_csv()

    except KeyboardInterrupt:
        print("\nScraping interrupted by user!")
        scraper.save_to_csv('movements_partial.csv')
        print("Partial results saved!")
    except Exception as e:
        print(f"\nAn error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        scraper.save_to_csv('movements_error.csv')
        print("Partial results saved due to error!")

if __name__ == "__main__":
    main()
# Out:
# Starting movement library scrape...
#
# Processing page 0
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library
#
# Found 10 potential movement rows
#
# Found movement: Back Leg Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-leg-swing
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180202184709if_/http://gymnasticswod.com/content/s00019?size=small
# Successfully parsed movement: Back Leg Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Lever
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-lever
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053739if_/http://gymnasticswod.com/content/a00010?size=small
# Successfully parsed movement: Back Lever
# Progress saved to movements_progress.json
#
# Found movement: Back Tuck
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-tuck
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053448if_/http://gymnasticswod.com/content/00088?size=small
# Successfully parsed movement: Back Tuck
# Progress saved to movements_progress.json
#
# Found movement: Back Uprise from Dip Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-uprise
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20180211105538if_/http://gymnasticswod.com/content/00106?size=small
# Successfully parsed movement: Back Uprise from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Uprise to Handstand from Dip Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-uprise-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180208233925if_/http://gymnasticswod.com/content/00109?size=small
# Successfully parsed movement: Back Uprise to Handstand from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Backward Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/backward-roll-floor
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180203000809if_/http://gymnasticswod.com/content/a00062?size=small
# Successfully parsed movement: Backward Roll
# Progress saved to movements_progress.json
#
# Found movement: Backward Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/backward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180202193554if_/http://gymnasticswod.com/content/a00019?size=small
# Successfully parsed movement: Backward Roll
# Progress saved to movements_progress.json
#
# Found movement: Bar Muscle Up
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/muscle-bar
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180206223554if_/http://gymnasticswod.com/content/00052?size=small
# Successfully parsed movement: Bar Muscle Up
# Progress saved to movements_progress.json
#
# Found movement: Bar Pull Up
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/pull-bar
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180420184935if_/http://gymnasticswod.com/content/00046?size=small
# Successfully parsed movement: Bar Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Bent Arm Back Extension Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/bent-arm-back-extension-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180211110952if_/http://gymnasticswod.com/content/a00068?size=small
# Successfully parsed movement: Bent Arm Back Extension Roll
# Progress saved to movements_progress.json
# Added 10 movements from page 0
# Total movements scraped: 10
# Waiting 18.1 seconds before next page...
#
# Processing page 1
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=1
#
# Found 10 potential movement rows
#
# Found movement: Bent Arm Back Extension Roll to Push Up Position
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/bent-arm-back-extension-roll-push-position
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011193627if_/http://gymnasticswod.com/content/a20060?size=small
# Successfully parsed movement: Bent Arm Back Extension Roll to Push Up Position
# Progress saved to movements_progress.json
#
# Found movement: Box Jump
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/box-jump
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111013222705if_/http://gymnasticswod.com/content/00093?size=small
# Successfully parsed movement: Box Jump
# Progress saved to movements_progress.json
#
# Found movement: Bridge Up
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/bridge
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011191117if_/http://gymnasticswod.com/content/a00092?size=small
# Successfully parsed movement: Bridge Up
# Progress saved to movements_progress.json
#
# Found movement: Broad Jump
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/broad-jump
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111007163533if_/http://gymnasticswod.com/content/00096?size=small
# Successfully parsed movement: Broad Jump
# Progress saved to movements_progress.json
#
# Found movement: Bulgarian Dip
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/bulgarian-dip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014025605if_/http://gymnasticswod.com/content/b00012?size=small
# Successfully parsed movement: Bulgarian Dip
# Progress saved to movements_progress.json
#
# Found movement: Burpee
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/burpee
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111007172306if_/http://gymnasticswod.com/content/00098?size=small
# Successfully parsed movement: Burpee
# Progress saved to movements_progress.json
#
# Found movement: Burpee Box Jump
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/burpee-box-jump
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011182556if_/http://gymnasticswod.com/content/b00039a?size=small
# Successfully parsed movement: Burpee Box Jump
# Progress saved to movements_progress.json
#
# Found movement: Butterfly Pull Up
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/butterfly-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014024829if_/http://gymnasticswod.com/content/00050?size=small
# Successfully parsed movement: Butterfly Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Candle Stick to Lever
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/candle-stick-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014003555if_/http://gymnasticswod.com/content/b00024?size=small
# Successfully parsed movement: Candle Stick to Lever
# Progress saved to movements_progress.json
#
# Found movement: Cartwheel
# Fetching: https://web.archive.org/web/20111013223505/http://gymnasticswod.com/content/cartwheel
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111011195633if_/http://gymnasticswod.com/content/00107?size=small
# Successfully parsed movement: Cartwheel
# Progress saved to movements_progress.json
# Added 10 movements from page 1
# Total movements scraped: 20
# Waiting 18.0 seconds before next page...
#
# Processing page 2
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=2
#
# Found 10 potential movement rows
#
# Found movement: Chest to Bar Butterfly Pull Up with Kick
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/chest-bar-butterfly-pull-kick
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011193059if_/http://gymnasticswod.com/content/s00013?size=small
# Successfully parsed movement: Chest to Bar Butterfly Pull Up with Kick
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Pull Up with Kip
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/chest-bar-pull-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011193146if_/http://gymnasticswod.com/content/s00009?size=small
# Successfully parsed movement: Chest to Bar Pull Up with Kip
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Pull Up with Kip and Kick
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/chest-bar-pull-kip-and-kick
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011195720if_/http://gymnasticswod.com/content/s00010?size=small
# Successfully parsed movement: Chest to Bar Pull Up with Kip and Kick
# Progress saved to movements_progress.json
#
# Found movement: Circles
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/circles
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011192738if_/http://gymnasticswod.com/content/a00026?size=small
# Successfully parsed movement: Circles
# Progress saved to movements_progress.json
#
# Found movement: Controlled Chest to Bar Butterfly Pull Up
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/controlled-chest-bar-butterfly-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011195745if_/http://gymnasticswod.com/content/s00012?size=small
# Successfully parsed movement: Controlled Chest to Bar Butterfly Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Dip
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/dip-rings
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111014030311if_/http://gymnasticswod.com/content/00143d?size=small
# Successfully parsed movement: Dip
# Progress saved to movements_progress.json
#
# Found movement: Dip
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/dip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111014030910if_/http://gymnasticswod.com/content/00101?size=small
# Successfully parsed movement: Dip
# Progress saved to movements_progress.json
#
# Found movement: Dip to Upper Arm Support
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/dip-upper-arm-support
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111011195439if_/http://gymnasticswod.com/content/b00020?size=small
# Successfully parsed movement: Dip to Upper Arm Support
# Progress saved to movements_progress.json
#
# Found movement: Dip with Kip
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/dip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011193420if_/http://gymnasticswod.com/content/s00017?size=small
# Successfully parsed movement: Dip with Kip
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Planche Through
# Fetching: https://web.archive.org/web/20111013222209/http://gymnasticswod.com/content/dumbbell-planche-through
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014031651if_/http://gymnasticswod.com/content/s00177?size=small
# Successfully parsed movement: Dumbbell Planche Through
# Progress saved to movements_progress.json
# Added 10 movements from page 2
# Total movements scraped: 30
# Waiting 17.5 seconds before next page...
#
# Processing page 3
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=3
#
# Found 10 potential movement rows
#
# Found movement: Dumbbell Planche Through to V Out
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/dumbbell-planche-through-v-out
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014031151if_/http://gymnasticswod.com/content/s00178?size=small
# Successfully parsed movement: Dumbbell Planche Through to V Out
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Straight Arm Press Out
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/dumbbell-straight-arm-press-out
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111014024413if_/http://gymnasticswod.com/content/s00184?size=small
# Successfully parsed movement: Dumbbell Straight Arm Press Out
# Progress saved to movements_progress.json
#
# Found movement: Dumbbells Overhead Hold
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/dumbbells-overhead-hold
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111114174053if_/http://gymnasticswod.com/content/s00170a?size=small
# Successfully parsed movement: Dumbbells Overhead Hold
# Progress saved to movements_progress.json
#
# Found movement: Dumbbells Overhead Press
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/dumbbells-overhead-press
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111115110417if_/http://gymnasticswod.com/content/s00171a?size=small
# Successfully parsed movement: Dumbbells Overhead Press
# Progress saved to movements_progress.json
#
# Found movement: Fedorchenko
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/fedorchenko
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011195646if_/http://gymnasticswod.com/content/a00041?size=small
# Successfully parsed movement: Fedorchenko
# Progress saved to movements_progress.json
#
# Found movement: Flare
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/flare
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111114201211if_/http://gymnasticswod.com/content/a00045?size=small
# Successfully parsed movement: Flare
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/forward-roll-floor
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111012145411if_/http://gymnasticswod.com/content/a00066?size=small
# Successfully parsed movement: Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/forward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014060809if_/http://gymnasticswod.com/content/a00021?size=small
# Successfully parsed movement: Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Pike Up to Handstand
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/forward-roll-pike-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111012151823if_/http://gymnasticswod.com/content/a00096?size=small
# Successfully parsed movement: Forward Roll Pike Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Straddle Up to Handstand
# Fetching: https://web.archive.org/web/20111013222330/http://gymnasticswod.com/content/forward-roll-straddle-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111019021514if_/http://gymnasticswod.com/content/a00095?size=small
# Successfully parsed movement: Forward Roll Straddle Up to Handstand
# Progress saved to movements_progress.json
# Added 10 movements from page 3
# Total movements scraped: 40
# Waiting 17.2 seconds before next page...
#
# Processing page 4
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=4
#
# Found 10 potential movement rows
#
# Found movement: Forward Roll Tuck Up to Handstand
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/forward-roll-tuck-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111013041228if_/http://gymnasticswod.com/content/a00094?size=small
# Successfully parsed movement: Forward Roll Tuck Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Front Leg Swing
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/front-leg-swing
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111011224936if_/http://gymnasticswod.com/content/s00022?size=small
# Successfully parsed movement: Front Leg Swing
# Progress saved to movements_progress.json
#
# Found movement: Front Lever
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/front-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014030107if_/http://gymnasticswod.com/content/a00013?size=small
# Successfully parsed movement: Front Lever
# Progress saved to movements_progress.json
#
# Found movement: Front Uprise from Dip Swing
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/front-uprise
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111019140030if_/http://gymnasticswod.com/content/00104b?size=small
# Successfully parsed movement: Front Uprise from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Glide Kip
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/glide-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128172624if_/http://gymnasticswod.com/content/a20067?size=small
# Successfully parsed movement: Glide Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Forward Roll
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/handstand-forward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20110909143457if_/http://gymnasticswod.com/content/a00063?size=small
# Successfully parsed movement: Handstand Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Handstand Hold Against Wall
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/handstand-hold-against-wall
# Found 1 iframes
# Successfully parsed movement: Handstand Hold Against Wall
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/handstand-push-floor
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111022092144if_/http://gymnasticswod.com/content/00115?size=small
# Successfully parsed movement: Handstand Push Up
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/handstand-push-rings
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111030130249if_/http://gymnasticswod.com/content/00124?size=small
# Successfully parsed movement: Handstand Push Up
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Kip
# Fetching: https://web.archive.org/web/20111013223446/http://gymnasticswod.com/content/handstand-push-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111023222848if_/http://gymnasticswod.com/content/00117?size=small
# Successfully parsed movement: Handstand Push Up with Kip
# Progress saved to movements_progress.json
# Added 10 movements from page 4
# Total movements scraped: 50
# Waiting 15.2 seconds before next page...
#
# Processing page 5
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=5
#
# Found 10 potential movement rows
#
# Found movement: Handstand Push Up with Wall
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/handstand-push-wall
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111022205637if_/http://gymnasticswod.com/content/00113a?size=small
# Successfully parsed movement: Handstand Push Up with Wall
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Wall and Kip
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/handstand-push-wall-and-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111022205511if_/http://gymnasticswod.com/content/00113b?size=small
# Successfully parsed movement: Handstand Push Up with Wall and Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Walk
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/handstand-walk
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111013223144if_/http://gymnasticswod.com/content/b00034?size=small
# Successfully parsed movement: Handstand Walk
# Progress saved to movements_progress.json
#
# Found movement: Handstand Walk Lateral
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/handstand-walk-lateral
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128125449if_/http://gymnasticswod.com/content/b00038?size=small
# Successfully parsed movement: Handstand Walk Lateral
# Progress saved to movements_progress.json
#
# Found movement: Headstand (Tripod)
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/headstand-tripod
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128131309if_/http://gymnasticswod.com/content/a20057?size=small
# Successfully parsed movement: Headstand (Tripod)
# Progress saved to movements_progress.json
#
# Found movement: Headstand (Tripod) to Push Up Position
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/headstand-tripod-push-position
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20110831120514if_/http://gymnasticswod.com/content/a20058?size=small
# Successfully parsed movement: Headstand (Tripod) to Push Up Position
# Progress saved to movements_progress.json
#
# Found movement: Headstand with Straight Arms
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/headstand-straight-arms
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128132604if_/http://gymnasticswod.com/content/a20059?size=small
# Successfully parsed movement: Headstand with Straight Arms
# Progress saved to movements_progress.json
#
# Found movement: Hollow Body
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/hollow-body
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014061430if_/http://gymnasticswod.com/content/a00052?size=small
# Successfully parsed movement: Hollow Body
# Progress saved to movements_progress.json
#
# Found movement: Hollow Rock
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/hollow-rock
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111013233344if_/http://gymnasticswod.com/content/00066?size=small
# Successfully parsed movement: Hollow Rock
# Progress saved to movements_progress.json
#
# Found movement: Jump Rope Double Unders
# Fetching: https://web.archive.org/web/20111013221310/http://gymnasticswod.com/content/jump-rope-double-unders
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111029142727if_/http://gymnasticswod.com/content/00007b?size=small
# Successfully parsed movement: Jump Rope Double Unders
# Progress saved to movements_progress.json
# Added 10 movements from page 5
# Total movements scraped: 60
# Waiting 15.4 seconds before next page...
#
# Processing page 6
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=6
#
# Found 10 potential movement rows
#
# Found movement: Jump Rope Singles
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/jump-rope-singles
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111128164013if_/http://gymnasticswod.com/content/00007a?size=small
# Successfully parsed movement: Jump Rope Singles
# Progress saved to movements_progress.json
#
# Found movement: Jump Rope Triple Unders
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/jump-rope-triple-unders
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111114110058if_/http://gymnasticswod.com/content/s00106?size=small
# Successfully parsed movement: Jump Rope Triple Unders
# Progress saved to movements_progress.json
#
# Found movement: Kick Up to Handstand
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/kick-handstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111114001954if_/http://gymnasticswod.com/content/a00050?size=small
# Successfully parsed movement: Kick Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Kip
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128161004if_/http://gymnasticswod.com/content/b00015?size=small
# Successfully parsed movement: Kip
# Progress saved to movements_progress.json
#
# Found movement: Kipping Pull Up
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/kipping-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20110917102049if_/http://gymnasticswod.com/content/00047?size=small
# Successfully parsed movement: Kipping Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Knees to Elbows
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/knees-elbows
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111112184428if_/http://gymnasticswod.com/content/00059?size=small
# Successfully parsed movement: Knees to Elbows
# Progress saved to movements_progress.json
#
# Found movement: Knees to Elbows with Kip
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/knees-elbows-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128155858if_/http://gymnasticswod.com/content/00063?size=small
# Successfully parsed movement: Knees to Elbows with Kip
# Progress saved to movements_progress.json
#
# Found movement: L Hang
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/l-hang
# Found 1 iframes
# Successfully parsed movement: L Hang
# Progress saved to movements_progress.json
#
# Found movement: L Seat
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/l-seat-rings
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111112045137if_/http://gymnasticswod.com/content/b00009a?size=small
# Successfully parsed movement: L Seat
# Progress saved to movements_progress.json
#
# Found movement: L Seat
# Fetching: https://web.archive.org/web/20111013222358/http://gymnasticswod.com/content/l-seat
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111030130825if_/http://gymnasticswod.com/content/00110c?size=small
# Successfully parsed movement: L Seat
# Progress saved to movements_progress.json
# Added 10 movements from page 6
# Total movements scraped: 70
# Waiting 16.4 seconds before next page...
#
# Processing page 7
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=7
#
# Found 10 potential movement rows
#
# Found movement: Lateral Push Up
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/lateral-push
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20110927104344if_/http://gymnasticswod.com/content/00029?size=small
# Successfully parsed movement: Lateral Push Up
# Progress saved to movements_progress.json
#
# Found movement: Leg Circles
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/leg-circles
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111007162112if_/http://gymnasticswod.com/content/00043?size=small
# Successfully parsed movement: Leg Circles
# Progress saved to movements_progress.json
#
# Found movement: Levers Progression - Pt.3
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/levers-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111112045147if_/http://gymnasticswod.com/content/p01004?size=small
# Successfully parsed movement: Levers Progression - Pt.3
# Progress saved to movements_progress.json
#
# Found movement: Maltese Bench Press
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/maltese-bench-press
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111113052901if_/http://gymnasticswod.com/content/s00176?size=small
# Successfully parsed movement: Maltese Bench Press
# Progress saved to movements_progress.json
#
# Found movement: Middle Split
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/middle-split
# Found 1 iframes
# Successfully parsed movement: Middle Split
# Progress saved to movements_progress.json
#
# Found movement: Mixed Grip
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/mixed-grip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128144034if_/http://gymnasticswod.com/content/00055?size=small
# Successfully parsed movement: Mixed Grip
# Progress saved to movements_progress.json
#
# Found movement: Mixed Grip with Kip
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/mixed-grip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128144856if_/http://gymnasticswod.com/content/00058?size=small
# Successfully parsed movement: Mixed Grip with Kip
# Progress saved to movements_progress.json
#
# Found movement: Mixed Seat
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/mixed-seat
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111112045152if_/http://gymnasticswod.com/content/00110b?size=small
# Successfully parsed movement: Mixed Seat
# Progress saved to movements_progress.json
#
# Found movement: Muscle Up with Kip
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/muscle-rings-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111112045207if_/http://gymnasticswod.com/content/00146?size=small
# Successfully parsed movement: Muscle Up with Kip
# Progress saved to movements_progress.json
#
# Found movement: Narrow Push Up
# Fetching: https://web.archive.org/web/20111013222156/http://gymnasticswod.com/content/narrow-push
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111128142911if_/http://gymnasticswod.com/content/00027?size=small
# Successfully parsed movement: Narrow Push Up
# Progress saved to movements_progress.json
# Added 10 movements from page 7
# Total movements scraped: 80
# Waiting 15.6 seconds before next page...
#
# Processing page 8
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=8
#
# Found 10 potential movement rows
#
# Found movement: Narrow Squat
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/narrow-squat
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111128153820if_/http://gymnasticswod.com/content/00070?size=small
# Successfully parsed movement: Narrow Squat
# Progress saved to movements_progress.json
#
# Found movement: Olympic Push Up
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/olympic-push
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111114160053if_/http://gymnasticswod.com/content/b00029?size=small
# Successfully parsed movement: Olympic Push Up
# Progress saved to movements_progress.json
#
# Found movement: One Leg Back Lever
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/one-leg-back-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111013030502if_/http://gymnasticswod.com/content/a00017?size=small
# Successfully parsed movement: One Leg Back Lever
# Progress saved to movements_progress.json
#
# Found movement: One Leg Candle Stick to Lever
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/one-leg-candle-stick-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111014002808if_/http://gymnasticswod.com/content/b00025a?size=small
# Successfully parsed movement: One Leg Candle Stick to Lever
# Progress saved to movements_progress.json
#
# Found movement: One Leg Front Lever
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/one-leg-front-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111103184221if_/http://gymnasticswod.com/content/a00018b?size=small
# Successfully parsed movement: One Leg Front Lever
# Progress saved to movements_progress.json
#
# Found movement: Overhand Grip
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/overhand-grip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20110901121240if_/http://gymnasticswod.com/content/00053?size=small
# Successfully parsed movement: Overhand Grip
# Progress saved to movements_progress.json
#
# Found movement: Overhand Grip with Kip
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/overhand-grip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20111128161404if_/http://gymnasticswod.com/content/00056?size=small
# Successfully parsed movement: Overhand Grip with Kip
# Progress saved to movements_progress.json
#
# Found movement: Pancake Split
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/pancake-split
# Found 1 iframes
# Successfully parsed movement: Pancake Split
# Progress saved to movements_progress.json
#
# Found movement: Pike Press to Handstand
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/pike-press-handstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111011193809if_/http://gymnasticswod.com/content/a00055?size=small
# Successfully parsed movement: Pike Press to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Pike Shoulder Press
# Fetching: https://web.archive.org/web/20111013222114/http://gymnasticswod.com/content/pike-shoulder-press
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20111112045359if_/http://gymnasticswod.com/content/a20054?size=small
# Successfully parsed movement: Pike Shoulder Press
# Progress saved to movements_progress.json
# Added 10 movements from page 8
# Total movements scraped: 90
# Waiting 15.4 seconds before next page...
#
# Processing page 9
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Attempt 1 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Waiting 30.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Attempt 2 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Waiting 60.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Attempt 3 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Waiting 120.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Attempt 4 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Waiting 240.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Attempt 5 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
# Failed to fetch https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=9
#
# Processing page 10
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=10
# Attempt 1 failed: 502 Server Error: Bad Gateway for url: https://web.archive.org/web/20241212030036/http://gymnasticswod.com/library?page=10
# Waiting 30.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=10
# Attempt 2 failed: 502 Server Error: Bad Gateway for url: https://web.archive.org/web/20241212030036/http://gymnasticswod.com/library?page=10
# Waiting 60.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=10
# Attempt 3 failed: 502 Server Error: Bad Gateway for url: https://web.archive.org/web/20241212030036/http://gymnasticswod.com/library?page=10
# Waiting 120.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=10
# Attempt 4 failed: 502 Server Error: Bad Gateway for url: https://web.archive.org/web/20241212030036/http://gymnasticswod.com/library?page=10
# Waiting 240.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=10
# Attempt 5 failed: 502 Server Error: Bad Gateway for url: https://web.archive.org/web/20241212030036/http://gymnasticswod.com/library?page=10
# Failed to fetch https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=10
#
# Processing page 11
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=11
#
# Found 0 potential movement rows
# No movements found on page 11 (Empty page count: 1)
#
# Processing page 12
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Attempt 1 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Waiting 30.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Attempt 2 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Waiting 60.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Attempt 3 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Waiting 120.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Attempt 4 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Waiting 240.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Attempt 5 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
# Failed to fetch https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=12
#
# Processing page 13
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Attempt 1 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Waiting 30.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Attempt 2 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Waiting 60.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Attempt 3 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Waiting 120.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Attempt 4 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Waiting 240.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Attempt 5 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
# Failed to fetch https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=13
#
# Processing page 14
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Attempt 1 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Waiting 30.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Attempt 2 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Waiting 60.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Attempt 3 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Waiting 120.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Attempt 4 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Waiting 240.0 seconds before retry...
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Attempt 5 failed: 404 Client Error: NOT FOUND for url: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Failed to fetch https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?page=14
# Too many consecutive errors, stopping scrape
#
# Saved 90 movements to movements.csv
# title: 90/90 rows have data (100.0%)
# instructions: 90/90 rows have data (100.0%)
# movement_url: 90/90 rows have data (100.0%)
# category: 90/90 rows have data (100.0%)
# apparatus: 90/90 rows have data (100.0%)
# movement_type: 90/90 rows have data (100.0%)
# video_src: 90/90 rows have data (100.0%)

# %%
## script for the full set of movements

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import json
from urllib.parse import urljoin

class MovementScraper:
    def __init__(self):
        self.wayback_base = "https://web.archive.org"
        self.base_url = f"{self.wayback_base}/web/20180202184709/http://gymnasticswod.com/library"
        self.movements = []
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Connection': 'keep-alive'
        }
        self.session = requests.Session()
        self.last_request_time = 0
        self.min_request_delay = 15

    def wait_between_requests(self):
        elapsed = time.time() - self.last_request_time
        if elapsed < self.min_request_delay:
            wait_time = self.min_request_delay - elapsed + random.uniform(1, 5)
            time.sleep(wait_time)
        self.last_request_time = time.time()

    def get_page_content(self, url, retry_count=5, initial_delay=30):
        if not url.startswith('http'):
            url = urljoin(self.wayback_base, url)

        for attempt in range(retry_count):
            try:
                self.wait_between_requests()
                print(f"Fetching: {url}")
                response = self.session.get(url, headers=self.headers, timeout=30)

                if response.status_code == 404:
                    print("Page not found (404) - reached the end of available pages")
                    return None

                if response.status_code == 429:  # Too Many Requests
                    delay = initial_delay * (attempt + 1)
                    print(f"Rate limited. Waiting {delay} seconds...")
                    time.sleep(delay)
                    continue

                response.raise_for_status()
                if response.status_code == 200:
                    return response.text

            except requests.RequestException as e:
                print(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt + 1 == retry_count:
                    print(f"Failed to fetch {url}")
                    return None

                delay = initial_delay * (2 ** attempt)
                print(f"Waiting {delay:.1f} seconds before retry...")
                time.sleep(delay)

        return None

    def extract_video_source(self, movement_url):
        content = self.get_page_content(movement_url)
        if not content:
            return ''

        soup = BeautifulSoup(content, 'html.parser')

        iframes = soup.find_all('iframe')
        print(f"Found {len(iframes)} iframes")

        for iframe in iframes:
            src = iframe.get('src', '')
            if not src or 'donate' in src:  # Skip donation iframe
                continue

            if not src.startswith('http'):
                src = urljoin(self.wayback_base, src)

            if 'size=small' in src:
                print(f"Found small video source: {src}")
                return src
            elif 'size=medium' in src:
                print(f"Found medium video source: {src}")
                return src

        return ''

    def parse_metadata(self, metadata_text):
        metadata = {
            'category': '',
            'apparatus': '',
            'movement_type': ''
        }

        if not metadata_text:
            return metadata

        try:
            parts = metadata_text.split('|')
            for part in parts:
                part = part.strip()
                if 'Category:' in part:
                    metadata['category'] = part.split('Category:')[1].strip()
                elif 'Apparatus:' in part:
                    metadata['apparatus'] = part.split('Apparatus:')[1].strip()
                elif 'Movement:' in part:
                    metadata['movement_type'] = part.split('Movement:')[1].strip()
        except Exception as e:
            print(f"Error parsing metadata: {str(e)}")

        return metadata

    def parse_movement(self, movement_row):
        try:
            # Look for links that are direct children or within movement title containers
            title = movement_row.find(['h2', 'h3'], class_=lambda x: x and 'title' in str(x))
            if title:
                title = title.find('a')
            if not title:
                title = movement_row.find('a', class_=lambda x: x is None or 'category' not in str(x))

            if not title:
                return None

            # Skip category links and non-movement content
            if any(word in title.text.lower() for word in ['category:', 'apparatus:', 'movement:', 'skill', 'strength']):
                return None

            movement_title = title.text.strip()
            movement_url = title['href']
            print(f"\nFound movement: {movement_title}")

            # Extract instructions
            instructions = []
            instruction_list = movement_row.find('ul')
            if instruction_list:
                instructions = [li.text.strip() for li in instruction_list.find_all('li')]
            else:
                # Look for instructions in field-items
                field_items = movement_row.find_all('div', class_='field-item')
                for item in field_items:
                    text = item.get_text(strip=True)
                    if text and not any(keyword in text.lower() for keyword in ['category:', 'apparatus:', 'movement:']):
                        instructions.append(text)

            # Get metadata from specific div
            metadata_div = movement_row.find(lambda tag: tag.name == 'div' and
                                          tag.text and
                                          ('Category:' in tag.text or
                                           'Apparatus:' in tag.text or
                                           'Movement:' in tag.text))

            metadata = self.parse_metadata(metadata_div.text if metadata_div else '')

            # Get video source
            full_url = urljoin(self.wayback_base, movement_url)
            video_src = self.extract_video_source(full_url)

            movement_data = {
                'title': movement_title,
                'instructions': '\n'.join(instructions),
                'movement_url': movement_url,
                'category': metadata['category'],
                'apparatus': metadata['apparatus'],
                'movement_type': metadata['movement_type'],
                'video_src': video_src
            }

            print(f"Successfully parsed movement: {movement_title}")
            return movement_data

        except Exception as e:
            print(f"Error parsing movement: {str(e)}")
            return None

    def scrape_movements(self, max_pages=None, start_page=0):
        page = start_page
        empty_page_count = 0

        while True:
            if max_pages is not None and page >= start_page + max_pages:
                print(f"Reached maximum number of pages ({max_pages})")
                break

            url = self.base_url
            if page > 0:
                url += f"?&&&sort_by=title&sort_order=ASC&items_per_page=10&page={page}"

            print(f"\nProcessing page {page}")
            content = self.get_page_content(url)

            if not content:
                break

            soup = BeautifulSoup(content, 'html.parser')

            # More specific movement detection
            movement_rows = soup.find_all(['div', 'li'],
                class_=lambda x: x and ('node-exercise' in x or 'views-row' in x))

            print(f"\nFound {len(movement_rows)} potential movement rows")

            if not movement_rows:
                empty_page_count += 1
                print(f"No movements found on page {page} (Empty page count: {empty_page_count})")
                if empty_page_count >= 3:
                    print("Found 3 consecutive empty pages, ending scrape")
                    break
                page += 1
                continue
            else:
                empty_page_count = 0

            movements_added = 0
            for row in movement_rows:
                movement_data = self.parse_movement(row)
                if movement_data:
                    self.movements.append(movement_data)
                    movements_added += 1
                    self.save_progress()

            print(f"Added {movements_added} movements from page {page}")
            print(f"Total movements scraped: {len(self.movements)}")

            page += 1
            delay = random.uniform(15, 20)
            print(f"Waiting {delay:.1f} seconds before next page...")
            time.sleep(delay)

    def save_progress(self, filename='movements_progress.json'):
        with open(filename, 'w') as f:
            json.dump(self.movements, f)
        print(f"Progress saved to {filename}")

    def load_progress(self, filename='movements_progress.json'):
        try:
            with open(filename, 'r') as f:
                self.movements = json.load(f)
            print(f"Loaded {len(self.movements)} movements from {filename}")
        except FileNotFoundError:
            print("No progress file found, starting fresh")

    def save_to_csv(self, filename='movements.csv'):
        if not self.movements:
            print("No movements to save!")
            return

        df = pd.DataFrame(self.movements)
        df.to_csv(filename, index=False)
        print(f"\nSaved {len(self.movements)} movements to {filename}")

        for column in df.columns:
            non_empty = df[column].notna().sum()
            print(f"{column}: {non_empty}/{len(df)} rows have data ({(non_empty/len(df)*100):.1f}%)")

def main():
    scraper = MovementScraper()
    try:
        print("Starting movement library scrape...")
        scraper.scrape_movements()
        scraper.save_to_csv()

    except KeyboardInterrupt:
        print("\nScraping interrupted by user!")
        scraper.save_to_csv('movements_partial.csv')
        print("Partial results saved!")
    except Exception as e:
        print(f"\nAn error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        scraper.save_to_csv('movements_error.csv')
        print("Partial results saved due to error!")

if __name__ == "__main__":
    main()
# Out:
# Starting movement library scrape...
#
# Processing page 0
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library
#
# Found 20 potential movement rows
#
# Found movement: Back Leg Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-leg-swing
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180202184709if_/http://gymnasticswod.com/content/s00019?size=small
# Successfully parsed movement: Back Leg Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Leg Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-leg-swing
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180202184709if_/http://gymnasticswod.com/content/s00019?size=small
# Successfully parsed movement: Back Leg Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Lever
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-lever
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053739if_/http://gymnasticswod.com/content/a00010?size=small
# Successfully parsed movement: Back Lever
# Progress saved to movements_progress.json
#
# Found movement: Back Lever
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-lever
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053739if_/http://gymnasticswod.com/content/a00010?size=small
# Successfully parsed movement: Back Lever
# Progress saved to movements_progress.json
#
# Found movement: Back Tuck
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-tuck
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053448if_/http://gymnasticswod.com/content/00088?size=small
# Successfully parsed movement: Back Tuck
# Progress saved to movements_progress.json
#
# Found movement: Back Tuck
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-tuck
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053448if_/http://gymnasticswod.com/content/00088?size=small
# Successfully parsed movement: Back Tuck
# Progress saved to movements_progress.json
#
# Found movement: Back Uprise from Dip Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-uprise
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20180211105538if_/http://gymnasticswod.com/content/00106?size=small
# Successfully parsed movement: Back Uprise from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Uprise from Dip Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-uprise
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20180211105538if_/http://gymnasticswod.com/content/00106?size=small
# Successfully parsed movement: Back Uprise from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Uprise to Handstand from Dip Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-uprise-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180208233925if_/http://gymnasticswod.com/content/00109?size=small
# Successfully parsed movement: Back Uprise to Handstand from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Back Uprise to Handstand from Dip Swing
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/back-uprise-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180208233925if_/http://gymnasticswod.com/content/00109?size=small
# Successfully parsed movement: Back Uprise to Handstand from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Backward Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/backward-roll-floor
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180203000809if_/http://gymnasticswod.com/content/a00062?size=small
# Successfully parsed movement: Backward Roll
# Progress saved to movements_progress.json
#
# Found movement: Backward Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/backward-roll-floor
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180203000809if_/http://gymnasticswod.com/content/a00062?size=small
# Successfully parsed movement: Backward Roll
# Progress saved to movements_progress.json
#
# Found movement: Backward Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/backward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180202193554if_/http://gymnasticswod.com/content/a00019?size=small
# Successfully parsed movement: Backward Roll
# Progress saved to movements_progress.json
#
# Found movement: Backward Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/backward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180202193554if_/http://gymnasticswod.com/content/a00019?size=small
# Successfully parsed movement: Backward Roll
# Progress saved to movements_progress.json
#
# Found movement: Bar Muscle Up
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/muscle-bar
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180206223554if_/http://gymnasticswod.com/content/00052?size=small
# Successfully parsed movement: Bar Muscle Up
# Progress saved to movements_progress.json
#
# Found movement: Bar Muscle Up
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/muscle-bar
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180206223554if_/http://gymnasticswod.com/content/00052?size=small
# Successfully parsed movement: Bar Muscle Up
# Progress saved to movements_progress.json
#
# Found movement: Bar Pull Up
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/pull-bar
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180420184935if_/http://gymnasticswod.com/content/00046?size=small
# Successfully parsed movement: Bar Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Bar Pull Up
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/pull-bar
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180420184935if_/http://gymnasticswod.com/content/00046?size=small
# Successfully parsed movement: Bar Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Bent Arm Back Extension Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/bent-arm-back-extension-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180211110952if_/http://gymnasticswod.com/content/a00068?size=small
# Successfully parsed movement: Bent Arm Back Extension Roll
# Progress saved to movements_progress.json
#
# Found movement: Bent Arm Back Extension Roll
# Fetching: https://web.archive.org/web/20180202215701/http://gymnasticswod.com/content/bent-arm-back-extension-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180211110952if_/http://gymnasticswod.com/content/a00068?size=small
# Successfully parsed movement: Bent Arm Back Extension Roll
# Progress saved to movements_progress.json
# Added 20 movements from page 0
# Total movements scraped: 20
# Waiting 19.6 seconds before next page...
#
# Processing page 1
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=1
#
# Found 20 potential movement rows
#
# Found movement: Bent Arm Back Extension Roll to Push Up Position
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bent-arm-back-extension-roll-push-position
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107162214if_/http://gymnasticswod.com/content/a20060?size=small
# Successfully parsed movement: Bent Arm Back Extension Roll to Push Up Position
# Progress saved to movements_progress.json
#
# Found movement: Bent Arm Back Extension Roll to Push Up Position
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bent-arm-back-extension-roll-push-position
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107162214if_/http://gymnasticswod.com/content/a20060?size=small
# Successfully parsed movement: Bent Arm Back Extension Roll to Push Up Position
# Progress saved to movements_progress.json
#
# Found movement: Bent Arm Pike Press to Handstand, Lower to Inverted Hang, Kip Up to Support
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bent-arm-pike-press-handstand-lower-inverted-hang-kip-support
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170930095301if_/http://gymnasticswod.com/content/r00034?size=small
# Successfully parsed movement: Bent Arm Pike Press to Handstand, Lower to Inverted Hang, Kip Up to Support
# Progress saved to movements_progress.json
#
# Found movement: Bent Arm Pike Press to Handstand, Lower to Inverted Hang, Kip Up to Support
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bent-arm-pike-press-handstand-lower-inverted-hang-kip-support
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170930095301if_/http://gymnasticswod.com/content/r00034?size=small
# Successfully parsed movement: Bent Arm Pike Press to Handstand, Lower to Inverted Hang, Kip Up to Support
# Progress saved to movements_progress.json
#
# Found movement: Box Jump
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/box-jump
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171011192605if_/http://gymnasticswod.com/content/00093?size=small
# Successfully parsed movement: Box Jump
# Progress saved to movements_progress.json
#
# Found movement: Box Jump
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/box-jump
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171011192605if_/http://gymnasticswod.com/content/00093?size=small
# Successfully parsed movement: Box Jump
# Progress saved to movements_progress.json
#
# Found movement: Bridge Up
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bridge
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107155312if_/http://gymnasticswod.com/content/a00092?size=small
# Successfully parsed movement: Bridge Up
# Progress saved to movements_progress.json
#
# Found movement: Bridge Up
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bridge
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107155312if_/http://gymnasticswod.com/content/a00092?size=small
# Successfully parsed movement: Bridge Up
# Progress saved to movements_progress.json
#
# Found movement: Broad Jump
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/broad-jump
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20170827090546if_/http://gymnasticswod.com/content/00096?size=small
# Successfully parsed movement: Broad Jump
# Progress saved to movements_progress.json
#
# Found movement: Broad Jump
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/broad-jump
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20170827090546if_/http://gymnasticswod.com/content/00096?size=small
# Successfully parsed movement: Broad Jump
# Progress saved to movements_progress.json
#
# Found movement: Bulgarian Dip
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bulgarian-dip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171221134500if_/http://gymnasticswod.com/content/b00012?size=small
# Successfully parsed movement: Bulgarian Dip
# Progress saved to movements_progress.json
#
# Found movement: Bulgarian Dip
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/bulgarian-dip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171221134500if_/http://gymnasticswod.com/content/b00012?size=small
# Successfully parsed movement: Bulgarian Dip
# Progress saved to movements_progress.json
#
# Found movement: Burpee
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/burpee
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20161105094534if_/http://gymnasticswod.com/content/00098?size=small
# Successfully parsed movement: Burpee
# Progress saved to movements_progress.json
#
# Found movement: Burpee
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/burpee
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20161105094534if_/http://gymnasticswod.com/content/00098?size=small
# Successfully parsed movement: Burpee
# Progress saved to movements_progress.json
#
# Found movement: Burpee Box Jump
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/burpee-box-jump
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170906202854if_/http://gymnasticswod.com/content/b00039a?size=small
# Successfully parsed movement: Burpee Box Jump
# Progress saved to movements_progress.json
#
# Found movement: Burpee Box Jump
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/burpee-box-jump
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170906202854if_/http://gymnasticswod.com/content/b00039a?size=small
# Successfully parsed movement: Burpee Box Jump
# Progress saved to movements_progress.json
#
# Found movement: Butterfly Pull Up
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/butterfly-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170801052819if_/http://gymnasticswod.com/content/00050?size=small
# Successfully parsed movement: Butterfly Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Butterfly Pull Up
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/butterfly-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170801052819if_/http://gymnasticswod.com/content/00050?size=small
# Successfully parsed movement: Butterfly Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Candle Stick to Lever
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/candle-stick-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108025439if_/http://gymnasticswod.com/content/b00024?size=small
# Successfully parsed movement: Candle Stick to Lever
# Progress saved to movements_progress.json
#
# Found movement: Candle Stick to Lever
# Fetching: https://web.archive.org/web/20171106135844/http://gymnasticswod.com/content/candle-stick-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108025439if_/http://gymnasticswod.com/content/b00024?size=small
# Successfully parsed movement: Candle Stick to Lever
# Progress saved to movements_progress.json
# Added 20 movements from page 1
# Total movements scraped: 40
# Waiting 18.0 seconds before next page...
#
# Processing page 2
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=2
#
# Found 20 potential movement rows
#
# Found movement: Cartwheel
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/cartwheel
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20160508043937if_/http://gymnasticswod.com/content/00107?size=small
# Successfully parsed movement: Cartwheel
# Progress saved to movements_progress.json
#
# Found movement: Cartwheel
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/cartwheel
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20160508043937if_/http://gymnasticswod.com/content/00107?size=small
# Successfully parsed movement: Cartwheel
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Butterfly Pull Up with Kick
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/chest-bar-butterfly-pull-kick
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015845if_/http://gymnasticswod.com/content/s00013?size=small
# Successfully parsed movement: Chest to Bar Butterfly Pull Up with Kick
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Butterfly Pull Up with Kick
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/chest-bar-butterfly-pull-kick
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015845if_/http://gymnasticswod.com/content/s00013?size=small
# Successfully parsed movement: Chest to Bar Butterfly Pull Up with Kick
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Pull Up with Kip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/chest-bar-pull-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015144if_/http://gymnasticswod.com/content/s00009?size=small
# Successfully parsed movement: Chest to Bar Pull Up with Kip
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Pull Up with Kip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/chest-bar-pull-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015144if_/http://gymnasticswod.com/content/s00009?size=small
# Successfully parsed movement: Chest to Bar Pull Up with Kip
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Pull Up with Kip and Kick
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/chest-bar-pull-kip-and-kick
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015536if_/http://gymnasticswod.com/content/s00010?size=small
# Successfully parsed movement: Chest to Bar Pull Up with Kip and Kick
# Progress saved to movements_progress.json
#
# Found movement: Chest to Bar Pull Up with Kip and Kick
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/chest-bar-pull-kip-and-kick
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015536if_/http://gymnasticswod.com/content/s00010?size=small
# Successfully parsed movement: Chest to Bar Pull Up with Kip and Kick
# Progress saved to movements_progress.json
#
# Found movement: Circles
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/circles
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180103045528if_/http://gymnasticswod.com/content/a00026?size=small
# Successfully parsed movement: Circles
# Progress saved to movements_progress.json
#
# Found movement: Circles
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/circles
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180103045528if_/http://gymnasticswod.com/content/a00026?size=small
# Successfully parsed movement: Circles
# Progress saved to movements_progress.json
#
# Found movement: Controlled Chest to Bar Butterfly Pull Up
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/controlled-chest-bar-butterfly-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015342if_/http://gymnasticswod.com/content/s00012?size=small
# Successfully parsed movement: Controlled Chest to Bar Butterfly Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Controlled Chest to Bar Butterfly Pull Up
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/controlled-chest-bar-butterfly-pull
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015342if_/http://gymnasticswod.com/content/s00012?size=small
# Successfully parsed movement: Controlled Chest to Bar Butterfly Pull Up
# Progress saved to movements_progress.json
#
# Found movement: Dip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip-rings
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171109204614if_/http://gymnasticswod.com/content/00143d?size=small
# Successfully parsed movement: Dip
# Progress saved to movements_progress.json
#
# Found movement: Dip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip-rings
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171109204614if_/http://gymnasticswod.com/content/00143d?size=small
# Successfully parsed movement: Dip
# Progress saved to movements_progress.json
#
# Found movement: Dip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171114055731if_/http://gymnasticswod.com/content/00101?size=small
# Successfully parsed movement: Dip
# Progress saved to movements_progress.json
#
# Found movement: Dip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171114055731if_/http://gymnasticswod.com/content/00101?size=small
# Successfully parsed movement: Dip
# Progress saved to movements_progress.json
#
# Found movement: Dip to Upper Arm Support
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip-upper-arm-support
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171225093219if_/http://gymnasticswod.com/content/b00020?size=small
# Successfully parsed movement: Dip to Upper Arm Support
# Progress saved to movements_progress.json
#
# Found movement: Dip to Upper Arm Support
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip-upper-arm-support
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171225093219if_/http://gymnasticswod.com/content/b00020?size=small
# Successfully parsed movement: Dip to Upper Arm Support
# Progress saved to movements_progress.json
#
# Found movement: Dip with Kip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110163942if_/http://gymnasticswod.com/content/s00017?size=small
# Successfully parsed movement: Dip with Kip
# Progress saved to movements_progress.json
#
# Found movement: Dip with Kip
# Fetching: https://web.archive.org/web/20171107053734/http://gymnasticswod.com/content/dip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110163942if_/http://gymnasticswod.com/content/s00017?size=small
# Successfully parsed movement: Dip with Kip
# Progress saved to movements_progress.json
# Added 20 movements from page 2
# Total movements scraped: 60
# Waiting 17.3 seconds before next page...
#
# Processing page 3
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=3
#
# Found 20 potential movement rows
#
# Found movement: Dumbbell Planche Through
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbell-planche-through
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015759if_/http://gymnasticswod.com/content/s00177?size=small
# Successfully parsed movement: Dumbbell Planche Through
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Planche Through
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbell-planche-through
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015759if_/http://gymnasticswod.com/content/s00177?size=small
# Successfully parsed movement: Dumbbell Planche Through
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Planche Through to V Out
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbell-planche-through-v-out
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015348if_/http://gymnasticswod.com/content/s00178?size=small
# Successfully parsed movement: Dumbbell Planche Through to V Out
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Planche Through to V Out
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbell-planche-through-v-out
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108015348if_/http://gymnasticswod.com/content/s00178?size=small
# Successfully parsed movement: Dumbbell Planche Through to V Out
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Straight Arm Press Out
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbell-straight-arm-press-out
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108023446if_/http://gymnasticswod.com/content/s00184?size=small
# Successfully parsed movement: Dumbbell Straight Arm Press Out
# Progress saved to movements_progress.json
#
# Found movement: Dumbbell Straight Arm Press Out
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbell-straight-arm-press-out
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108023446if_/http://gymnasticswod.com/content/s00184?size=small
# Successfully parsed movement: Dumbbell Straight Arm Press Out
# Progress saved to movements_progress.json
#
# Found movement: Dumbbells Overhead Hold
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbells-overhead-hold
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171021145139if_/http://gymnasticswod.com/content/s00170a?size=small
# Successfully parsed movement: Dumbbells Overhead Hold
# Progress saved to movements_progress.json
#
# Found movement: Dumbbells Overhead Hold
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbells-overhead-hold
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171021145139if_/http://gymnasticswod.com/content/s00170a?size=small
# Successfully parsed movement: Dumbbells Overhead Hold
# Progress saved to movements_progress.json
#
# Found movement: Dumbbells Overhead Press
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbells-overhead-press
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171229095120if_/http://gymnasticswod.com/content/s00171a?size=small
# Successfully parsed movement: Dumbbells Overhead Press
# Progress saved to movements_progress.json
#
# Found movement: Dumbbells Overhead Press
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/dumbbells-overhead-press
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171229095120if_/http://gymnasticswod.com/content/s00171a?size=small
# Successfully parsed movement: Dumbbells Overhead Press
# Progress saved to movements_progress.json
#
# Found movement: Fedorchenko
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/fedorchenko
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171102091612if_/http://gymnasticswod.com/content/a00041?size=small
# Successfully parsed movement: Fedorchenko
# Progress saved to movements_progress.json
#
# Found movement: Fedorchenko
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/fedorchenko
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171102091612if_/http://gymnasticswod.com/content/a00041?size=small
# Successfully parsed movement: Fedorchenko
# Progress saved to movements_progress.json
#
# Found movement: Flare
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/flare
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180102222301if_/http://gymnasticswod.com/content/a00045?size=small
# Successfully parsed movement: Flare
# Progress saved to movements_progress.json
#
# Found movement: Flare
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/flare
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180102222301if_/http://gymnasticswod.com/content/a00045?size=small
# Successfully parsed movement: Flare
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/forward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20161017230953if_/http://gymnasticswod.com/content/a00021?size=small
# Successfully parsed movement: Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/forward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20161017230953if_/http://gymnasticswod.com/content/a00021?size=small
# Successfully parsed movement: Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/forward-roll-floor
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171102034331if_/http://gymnasticswod.com/content/a00066?size=small
# Successfully parsed movement: Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/forward-roll-floor
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171102034331if_/http://gymnasticswod.com/content/a00066?size=small
# Successfully parsed movement: Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Pike Up to Handstand
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/forward-roll-pike-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171104015843if_/http://gymnasticswod.com/content/a00096?size=small
# Successfully parsed movement: Forward Roll Pike Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Pike Up to Handstand
# Fetching: https://web.archive.org/web/20171107054430/http://gymnasticswod.com/content/forward-roll-pike-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171104015843if_/http://gymnasticswod.com/content/a00096?size=small
# Successfully parsed movement: Forward Roll Pike Up to Handstand
# Progress saved to movements_progress.json
# Added 20 movements from page 3
# Total movements scraped: 80
# Waiting 17.4 seconds before next page...
#
# Processing page 4
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=4
#
# Found 20 potential movement rows
#
# Found movement: Forward Roll Straddle Up to Handstand
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/forward-roll-straddle-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171222144952if_/http://gymnasticswod.com/content/a00095?size=small
# Successfully parsed movement: Forward Roll Straddle Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Straddle Up to Handstand
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/forward-roll-straddle-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171222144952if_/http://gymnasticswod.com/content/a00095?size=small
# Successfully parsed movement: Forward Roll Straddle Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll to Inverted Hang
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/forward-roll-inverted-hang
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170930171228if_/http://gymnasticswod.com/content/r00022a?size=small
# Successfully parsed movement: Forward Roll to Inverted Hang
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll to Inverted Hang
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/forward-roll-inverted-hang
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170930171228if_/http://gymnasticswod.com/content/r00022a?size=small
# Successfully parsed movement: Forward Roll to Inverted Hang
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Tuck Up to Handstand
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/forward-roll-tuck-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171018115756if_/http://gymnasticswod.com/content/a00094?size=small
# Successfully parsed movement: Forward Roll Tuck Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Forward Roll Tuck Up to Handstand
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/forward-roll-tuck-handstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171018115756if_/http://gymnasticswod.com/content/a00094?size=small
# Successfully parsed movement: Forward Roll Tuck Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Front Leg Swing
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/front-leg-swing
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171101121137if_/http://gymnasticswod.com/content/s00022?size=small
# Successfully parsed movement: Front Leg Swing
# Progress saved to movements_progress.json
#
# Found movement: Front Leg Swing
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/front-leg-swing
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171101121137if_/http://gymnasticswod.com/content/s00022?size=small
# Successfully parsed movement: Front Leg Swing
# Progress saved to movements_progress.json
#
# Found movement: Front Lever
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/front-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108022423if_/http://gymnasticswod.com/content/a00013?size=small
# Successfully parsed movement: Front Lever
# Progress saved to movements_progress.json
#
# Found movement: Front Lever
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/front-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171108022423if_/http://gymnasticswod.com/content/a00013?size=small
# Successfully parsed movement: Front Lever
# Progress saved to movements_progress.json
#
# Found movement: Front Uprise from Dip Swing
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/front-uprise
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171110164315if_/http://gymnasticswod.com/content/00104b?size=small
# Successfully parsed movement: Front Uprise from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Front Uprise from Dip Swing
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/front-uprise
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171110164315if_/http://gymnasticswod.com/content/00104b?size=small
# Successfully parsed movement: Front Uprise from Dip Swing
# Progress saved to movements_progress.json
#
# Found movement: Glide Kip
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/glide-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20160703075827if_/http://gymnasticswod.com/content/a20067?size=small
# Successfully parsed movement: Glide Kip
# Progress saved to movements_progress.json
#
# Found movement: Glide Kip
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/glide-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20160703075827if_/http://gymnasticswod.com/content/a20067?size=small
# Successfully parsed movement: Glide Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Forward Roll
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/handstand-forward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107175716if_/http://gymnasticswod.com/content/a00063?size=small
# Successfully parsed movement: Handstand Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Handstand Forward Roll
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/handstand-forward-roll
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107175716if_/http://gymnasticswod.com/content/a00063?size=small
# Successfully parsed movement: Handstand Forward Roll
# Progress saved to movements_progress.json
#
# Found movement: Handstand Hold Against Wall
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/handstand-hold-against-wall
# Found 1 iframes
# Successfully parsed movement: Handstand Hold Against Wall
# Progress saved to movements_progress.json
#
# Found movement: Handstand Hold Against Wall
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/handstand-hold-against-wall
# Found 1 iframes
# Successfully parsed movement: Handstand Hold Against Wall
# Progress saved to movements_progress.json
#
# Found movement: Handstand on Rings
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/handstand-rings
# Found 1 iframes
# Successfully parsed movement: Handstand on Rings
# Progress saved to movements_progress.json
#
# Found movement: Handstand on Rings
# Fetching: https://web.archive.org/web/20171107055355/http://gymnasticswod.com/content/handstand-rings
# Found 1 iframes
# Successfully parsed movement: Handstand on Rings
# Progress saved to movements_progress.json
# Added 20 movements from page 4
# Total movements scraped: 100
# Waiting 17.7 seconds before next page...
#
# Processing page 5
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=5
#
# Found 20 potential movement rows
#
# Found movement: Handstand Push Up
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-rings
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053656if_/http://gymnasticswod.com/content/00124?size=small
# Successfully parsed movement: Handstand Push Up
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-rings
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053656if_/http://gymnasticswod.com/content/00124?size=small
# Successfully parsed movement: Handstand Push Up
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-floor
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053724if_/http://gymnasticswod.com/content/00115?size=small
# Successfully parsed movement: Handstand Push Up
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-floor
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053724if_/http://gymnasticswod.com/content/00115?size=small
# Successfully parsed movement: Handstand Push Up
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Kip
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053443if_/http://gymnasticswod.com/content/00117?size=small
# Successfully parsed movement: Handstand Push Up with Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Kip
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171107053443if_/http://gymnasticswod.com/content/00117?size=small
# Successfully parsed movement: Handstand Push Up with Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Wall
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-wall
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171114192350if_/http://gymnasticswod.com/content/00113a?size=small
# Successfully parsed movement: Handstand Push Up with Wall
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Wall
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-wall
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171114192350if_/http://gymnasticswod.com/content/00113a?size=small
# Successfully parsed movement: Handstand Push Up with Wall
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Wall and Kip
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-wall-and-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171011160142if_/http://gymnasticswod.com/content/00113b?size=small
# Successfully parsed movement: Handstand Push Up with Wall and Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Push Up with Wall and Kip
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-push-wall-and-kip
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171011160142if_/http://gymnasticswod.com/content/00113b?size=small
# Successfully parsed movement: Handstand Push Up with Wall and Kip
# Progress saved to movements_progress.json
#
# Found movement: Handstand Walk
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-walk
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108025454if_/http://gymnasticswod.com/content/b00034?size=small
# Successfully parsed movement: Handstand Walk
# Progress saved to movements_progress.json
#
# Found movement: Handstand Walk
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-walk
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108025454if_/http://gymnasticswod.com/content/b00034?size=small
# Successfully parsed movement: Handstand Walk
# Progress saved to movements_progress.json
#
# Found movement: Handstand Walk Lateral
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-walk-lateral
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171011190335if_/http://gymnasticswod.com/content/b00038?size=small
# Successfully parsed movement: Handstand Walk Lateral
# Progress saved to movements_progress.json
#
# Found movement: Handstand Walk Lateral
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/handstand-walk-lateral
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171011190335if_/http://gymnasticswod.com/content/b00038?size=small
# Successfully parsed movement: Handstand Walk Lateral
# Progress saved to movements_progress.json
#
# Found movement: Headstand (Tripod)
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/headstand-tripod
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171230061522if_/http://gymnasticswod.com/content/a20057?size=small
# Successfully parsed movement: Headstand (Tripod)
# Progress saved to movements_progress.json
#
# Found movement: Headstand (Tripod)
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/headstand-tripod
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171230061522if_/http://gymnasticswod.com/content/a20057?size=small
# Successfully parsed movement: Headstand (Tripod)
# Progress saved to movements_progress.json
#
# Found movement: Headstand (Tripod) to Push Up Position
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/headstand-tripod-push-position
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170921210818if_/http://gymnasticswod.com/content/a20058?size=small
# Successfully parsed movement: Headstand (Tripod) to Push Up Position
# Progress saved to movements_progress.json
#
# Found movement: Headstand (Tripod) to Push Up Position
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/headstand-tripod-push-position
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170921210818if_/http://gymnasticswod.com/content/a20058?size=small
# Successfully parsed movement: Headstand (Tripod) to Push Up Position
# Progress saved to movements_progress.json
#
# Found movement: Headstand with Straight Arms
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/headstand-straight-arms
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20160507015028if_/http://gymnasticswod.com/content/a20059?size=small
# Successfully parsed movement: Headstand with Straight Arms
# Progress saved to movements_progress.json
#
# Found movement: Headstand with Straight Arms
# Fetching: https://web.archive.org/web/20171107055400/http://gymnasticswod.com/content/headstand-straight-arms
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20160507015028if_/http://gymnasticswod.com/content/a20059?size=small
# Successfully parsed movement: Headstand with Straight Arms
# Progress saved to movements_progress.json
# Added 20 movements from page 5
# Total movements scraped: 120
# Waiting 19.8 seconds before next page...
#
# Processing page 6
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=6
#
# Found 20 potential movement rows
#
# Found movement: Hip Shoots
# Fetching: https://web.archive.org/web/20171107053537/http://gymnasticswod.com/content/hip-shoots
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108015353if_/http://gymnasticswod.com/content/00032a?size=small
# Successfully parsed movement: Hip Shoots
# Progress saved to movements_progress.json
#
# Found movement: Hip Shoots
# Fetching: https://web.archive.org/web/20171107053537/http://gymnasticswod.com/content/hip-shoots
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108015353if_/http://gymnasticswod.com/content/00032a?size=small
# Successfully parsed movement: Hip Shoots
# Progress saved to movements_progress.json
#
# Found movement: Hollow Body
# Fetching: https://web.archive.org/web/20171107053537/http://gymnasticswod.com/content/hollow-body
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171026073636if_/http://gymnasticswod.com/content/a00052?size=small
# Successfully parsed movement: Hollow Body
# Progress saved to movements_progress.json
#
# Found movement: Hollow Body
# Fetching: https://web.archive.org/web/20171107053537/http://gymnasticswod.com/content/hollow-body
# ...
# Successfully parsed movement: Tripod Pike Up to Headstand
# Progress saved to movements_progress.json
#
# Found movement: Tripod Straddle Up to Headstand
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tripod-straddle-headstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171113180426if_/http://gymnasticswod.com/content/a20063a?size=small
# Successfully parsed movement: Tripod Straddle Up to Headstand
# Progress saved to movements_progress.json
#
# Found movement: Tripod Straddle Up to Headstand
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tripod-straddle-headstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171113180426if_/http://gymnasticswod.com/content/a20063a?size=small
# Successfully parsed movement: Tripod Straddle Up to Headstand
# Progress saved to movements_progress.json
#
# Found movement: Tripod Tuck Up to Headstand
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tripod-tuck-headstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170811050817if_/http://gymnasticswod.com/content/a20062?size=small
# Successfully parsed movement: Tripod Tuck Up to Headstand
# Progress saved to movements_progress.json
#
# Found movement: Tripod Tuck Up to Headstand
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tripod-tuck-headstand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170811050817if_/http://gymnasticswod.com/content/a20062?size=small
# Successfully parsed movement: Tripod Tuck Up to Headstand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Back Lever
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-back-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107055607if_/http://gymnasticswod.com/content/a00016?size=small
# Successfully parsed movement: Tuck Back Lever
# Progress saved to movements_progress.json
#
# Found movement: Tuck Back Lever
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-back-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171107055607if_/http://gymnasticswod.com/content/a00016?size=small
# Successfully parsed movement: Tuck Back Lever
# Progress saved to movements_progress.json
#
# Found movement: Tuck Front Lever
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-front-lever
# Found 1 iframes
# Successfully parsed movement: Tuck Front Lever
# Progress saved to movements_progress.json
#
# Found movement: Tuck Front Lever
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-front-lever
# Found 1 iframes
# Successfully parsed movement: Tuck Front Lever
# Progress saved to movements_progress.json
#
# Found movement: Tuck Jump
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-jump
# Found 1 iframes
# Successfully parsed movement: Tuck Jump
# Progress saved to movements_progress.json
#
# Found movement: Tuck Jump
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-jump
# Found 1 iframes
# Successfully parsed movement: Tuck Jump
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Handstand
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-press-handstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171229213219if_/http://gymnasticswod.com/content/a00059?size=small
# Successfully parsed movement: Tuck Press to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Handstand
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-press-handstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171229213219if_/http://gymnasticswod.com/content/a00059?size=small
# Successfully parsed movement: Tuck Press to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Kipping Handstand Push Up on Rings, Lower to Inverted Hang, Kip Up to Support
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-press-kipping-handstand-push-rings-lower-inverted-hang-kip-support
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110213949if_/http://gymnasticswod.com/content/r00031?size=small
# Successfully parsed movement: Tuck Press to Kipping Handstand Push Up on Rings, Lower to Inverted Hang, Kip Up to Support
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Kipping Handstand Push Up on Rings, Lower to Inverted Hang, Kip Up to Support
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-press-kipping-handstand-push-rings-lower-inverted-hang-kip-support
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110213949if_/http://gymnasticswod.com/content/r00031?size=small
# Successfully parsed movement: Tuck Press to Kipping Handstand Push Up on Rings, Lower to Inverted Hang, Kip Up to Support
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Kipping Handstand Push Up on Rings, Reverse
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-press-kipping-handstand-push-rings-reverse
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171019031332if_/http://gymnasticswod.com/content/r00025?size=small
# Successfully parsed movement: Tuck Press to Kipping Handstand Push Up on Rings, Reverse
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Kipping Handstand Push Up on Rings, Reverse
# Fetching: https://web.archive.org/web/20171102162351/http://gymnasticswod.com/content/tuck-press-kipping-handstand-push-rings-reverse
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171019031332if_/http://gymnasticswod.com/content/r00025?size=small
# Successfully parsed movement: Tuck Press to Kipping Handstand Push Up on Rings, Reverse
# Progress saved to movements_progress.json
# Added 20 movements from page 15
# Total movements scraped: 320
# Waiting 16.4 seconds before next page...
#
# Processing page 16
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=16
#
# Found 20 potential movement rows
#
# Found movement: Tuck Press to Shoulder Stand
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-press-shoulder-stand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170831102325if_/http://gymnasticswod.com/content/r00024?size=small
# Successfully parsed movement: Tuck Press to Shoulder Stand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Shoulder Stand
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-press-shoulder-stand
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170831102325if_/http://gymnasticswod.com/content/r00024?size=small
# Successfully parsed movement: Tuck Press to Shoulder Stand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Tucked Shoulder Stand
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-press-tucked-shoulder-stand
# Found 1 iframes
# Successfully parsed movement: Tuck Press to Tucked Shoulder Stand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Press to Tucked Shoulder Stand
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-press-tucked-shoulder-stand
# Found 1 iframes
# Successfully parsed movement: Tuck Press to Tucked Shoulder Stand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Seat
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-seat
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171225092421if_/http://gymnasticswod.com/content/00110a?size=small
# Successfully parsed movement: Tuck Seat
# Progress saved to movements_progress.json
#
# Found movement: Tuck Seat
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-seat
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171225092421if_/http://gymnasticswod.com/content/00110a?size=small
# Successfully parsed movement: Tuck Seat
# Progress saved to movements_progress.json
#
# Found movement: Tuck Shoulder Press
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-shoulder-press
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110213511if_/http://gymnasticswod.com/content/a20050?size=small
# Successfully parsed movement: Tuck Shoulder Press
# Progress saved to movements_progress.json
#
# Found movement: Tuck Shoulder Press
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-shoulder-press
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110213511if_/http://gymnasticswod.com/content/a20050?size=small
# Successfully parsed movement: Tuck Shoulder Press
# Progress saved to movements_progress.json
#
# Found movement: Tuck to Lever
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110204137if_/http://gymnasticswod.com/content/b00025b?size=small
# Successfully parsed movement: Tuck to Lever
# Progress saved to movements_progress.json
#
# Found movement: Tuck to Lever
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-lever
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20171110204137if_/http://gymnasticswod.com/content/b00025b?size=small
# Successfully parsed movement: Tuck to Lever
# Progress saved to movements_progress.json
#
# Found movement: Tuck Up
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108025417if_/http://gymnasticswod.com/content/00040?size=small
# Successfully parsed movement: Tuck Up
# Progress saved to movements_progress.json
#
# Found movement: Tuck Up
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108025417if_/http://gymnasticswod.com/content/00040?size=small
# Successfully parsed movement: Tuck Up
# Progress saved to movements_progress.json
#
# Found movement: Tuck Up to Handstand
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-handstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20160728021516if_/http://gymnasticswod.com/content/r00071?size=small
# Successfully parsed movement: Tuck Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Tuck Up to Handstand
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/tuck-handstand
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20160728021516if_/http://gymnasticswod.com/content/r00071?size=small
# Successfully parsed movement: Tuck Up to Handstand
# Progress saved to movements_progress.json
#
# Found movement: Underhand Grip
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/underhand-grip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170905163947if_/http://gymnasticswod.com/content/00054?size=small
# Successfully parsed movement: Underhand Grip
# Progress saved to movements_progress.json
#
# Found movement: Underhand Grip
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/underhand-grip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20170905163947if_/http://gymnasticswod.com/content/00054?size=small
# Successfully parsed movement: Underhand Grip
# Progress saved to movements_progress.json
#
# Found movement: Underhand Grip with Kip
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/underhand-grip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180227093709if_/http://gymnasticswod.com/content/00057?size=small
# Successfully parsed movement: Underhand Grip with Kip
# Progress saved to movements_progress.json
#
# Found movement: Underhand Grip with Kip
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/underhand-grip-kip
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20180227093709if_/http://gymnasticswod.com/content/00057?size=small
# Successfully parsed movement: Underhand Grip with Kip
# Progress saved to movements_progress.json
#
# Found movement: V Out
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/v-out
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108042016if_/http://gymnasticswod.com/content/a20021?size=small
# Successfully parsed movement: V Out
# Progress saved to movements_progress.json
#
# Found movement: V Out
# Fetching: https://web.archive.org/web/20171102152513/http://gymnasticswod.com/content/v-out
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108042016if_/http://gymnasticswod.com/content/a20021?size=small
# Successfully parsed movement: V Out
# Progress saved to movements_progress.json
# Added 20 movements from page 16
# Total movements scraped: 340
# Waiting 16.2 seconds before next page...
#
# Processing page 17
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
#
# Found 4 potential movement rows
#
# Found movement: V Up
# Fetching: https://web.archive.org/web/20171107055348/http://gymnasticswod.com/content/v
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108022443if_/http://gymnasticswod.com/content/00041?size=small
# Successfully parsed movement: V Up
# Progress saved to movements_progress.json
#
# Found movement: V Up
# Fetching: https://web.archive.org/web/20171107055348/http://gymnasticswod.com/content/v
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20171108022443if_/http://gymnasticswod.com/content/00041?size=small
# Successfully parsed movement: V Up
# Progress saved to movements_progress.json
#
# Found movement: Wide Push Up
# Fetching: https://web.archive.org/web/20171107055348/http://gymnasticswod.com/content/wide-push
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20170619060749if_/http://gymnasticswod.com/content/00025?size=small
# Successfully parsed movement: Wide Push Up
# Progress saved to movements_progress.json
#
# Found movement: Wide Push Up
# Fetching: https://web.archive.org/web/20171107055348/http://gymnasticswod.com/content/wide-push
# Found 7 iframes
# Found small video source: https://web.archive.org/web/20170619060749if_/http://gymnasticswod.com/content/00025?size=small
# Successfully parsed movement: Wide Push Up
# Progress saved to movements_progress.json
# Added 4 movements from page 17
# Total movements scraped: 344
# Waiting 17.6 seconds before next page...
#
# Processing page 18
# Fetching: https://web.archive.org/web/20180202184709/http://gymnasticswod.com/library?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=18
# Page not found (404) - reached the end of available pages
#
# Saved 344 movements to movements.csv
# title: 344/344 rows have data (100.0%)
# instructions: 344/344 rows have data (100.0%)
# movement_url: 344/344 rows have data (100.0%)
# category: 344/344 rows have data (100.0%)
# apparatus: 344/344 rows have data (100.0%)
# movement_type: 344/344 rows have data (100.0%)
# video_src: 344/344 rows have data (100.0%)

# %%
# some data analysis
import pandas as pd
import re

def analyze_csv():
    # Read the CSV file
    df = pd.read_csv('movements.csv')

    print("Data Quality Analysis:")
    print("-" * 50)

    # Basic stats
    print(f"\nTotal movements: {len(df)}")

    # Check categories
    print("\nCategories:")
    print(df['category'].value_counts())

    # Check apparatus
    print("\nApparatus:")
    print(df['apparatus'].value_counts())

    # Check video sources
    print("\nVideo source analysis:")
    video_urls = df['video_src'].dropna()
    print(f"Number of video sources: {len(video_urls)}")

    # Check video URL format
    valid_format = video_urls.str.contains(r'gymnasticswod\.com/content/s\d+\?size=', case=False)
    print(f"Valid URL format: {valid_format.sum()}/{len(video_urls)}")

    # Sample of data
    print("\nSample entries (first 3):")
    for idx, row in df.head(3).iterrows():
        print(f"\nMovement {idx + 1}:")
        print(f"Title: {row['title']}")
        print(f"Category: {row['category']}")
        print(f"Apparatus: {row['apparatus']}")
        print(f"Instructions: {row['instructions'][:100]}...")
        print(f"Video: {row['video_src']}")

if __name__ == "__main__":
    analyze_csv()
# Out:
# Data Quality Analysis:
# --------------------------------------------------
#
# Total movements: 344
#
# Categories:
# category
# Functional         132
# Strength           112
# Skill               78
# SkillStrength       12
# FunctionalSkill     10
# Name: count, dtype: int64
#
# Apparatus:
# apparatus
# Floor                   148
# Rings                    64
# High Bar                 44
# P-Bars                   32
# Dumbbells                20
# Rope                     12
# Pommel HorseMushroom      8
# Jump Rope                 6
# Box                       4
# U-BarsHigh Bar            2
# Male                      2
# Name: count, dtype: int64
#
# Video source analysis:
# Number of video sources: 320
# Valid URL format: 38/320
#
# Sample entries (first 3):
#
# Movement 1:
# Title: Back Leg Swing
# Category: Functional
# Apparatus: Floor
# Instructions: Stand with one leg straight under your hip and hold onto the wall or a low bar for balance
# Keep your...
# Video: https://web.archive.org/web/20180202184709if_/http://gymnasticswod.com/content/s00019?size=small
#
# Movement 2:
# Title: Back Leg Swing
# Category: Functional
# Apparatus: Floor
# Instructions: Stand with one leg straight under your hip and hold onto the wall or a low bar for balance
# Keep your...
# Video: https://web.archive.org/web/20180202184709if_/http://gymnasticswod.com/content/s00019?size=small
#
# Movement 3:
# Title: Back Lever
# Category: Strength
# Apparatus: Rings
# Instructions: Find a hollow body position while in the inverted hang
# Without breaking hollow allow your hips and t...
# Video: https://web.archive.org/web/20171107053739if_/http://gymnasticswod.com/content/a00010?size=small

# %%
import pandas as pd
import json

# Read the CSV file
df = pd.read_csv('movements.csv')

# Display the columns
print("Columns in the dataset:")
print(df.columns)
print("\nSample movement entry (first row):")
print(df.iloc[0].to_dict())

# Check which columns have data and which are empty
print("\nColumn completeness:")
for column in df.columns:
    non_empty = df[column].notna().sum()
    print(f"{column}: {non_empty}/{len(df)} rows have data ({(non_empty/len(df)*100):.1f}%)")

# Show a few example instructions
print("\nSample movement instructions:")
print(df[['title', 'instructions']].head(3))
# Out:
# Columns in the dataset:
# Index(['title', 'instructions', 'movement_url', 'category', 'apparatus',
#        'movement_type', 'video_src_small', 'video_src_medium',
#        'video_src_large'],
#       dtype='object')
#
# Sample movement entry (first row):
# {'title': 'Back Leg Swing', 'instructions': 'Stand with one leg straight under your hip and hold onto the wall or a low bar for balance\nKeep your legs straight, belly tight, and butt squeezed as you kick your other leg back and up behind you\nDrive your heel as high as you can while maintaining a neutral spine and straight leg\nYou should be hinging only at the hip, do not bend the legs while swinging and try to point your toe', 'movement_url': '/web/20180204210343/http://gymnasticswod.com/content/back-leg-swing', 'category': 'Functional', 'apparatus': 'Floor', 'movement_type': 'Leg Swing', 'video_src_small': nan, 'video_src_medium': nan, 'video_src_large': nan}
#
# Column completeness:
# title: 210/210 rows have data (100.0%)
# instructions: 135/210 rows have data (64.3%)
# movement_url: 210/210 rows have data (100.0%)
# category: 210/210 rows have data (100.0%)
# apparatus: 210/210 rows have data (100.0%)
# movement_type: 210/210 rows have data (100.0%)
# video_src_small: 20/210 rows have data (9.5%)
# video_src_medium: 20/210 rows have data (9.5%)
# video_src_large: 10/210 rows have data (4.8%)
#
# Sample movement instructions:
#             title                                       instructions
# 0  Back Leg Swing  Stand with one leg straight under your hip and...
# 1      Back Lever  Find a hollow body position while in the inver...
# 2       Back Tuck  Stand tall with abs and butt on\nInitiate stra...

# %%
pip install google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.10/dist-packages (2.151.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.10/dist-packages (1.2.1)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (0.22.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.27.0)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (2.19.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.25.5)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.25.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (4.9)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0.dev0,>=1.32.0->google-api-python-client) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2024.8.30)

# %%
### code used to import to Google sheets
from google.colab import auth
import pandas as pd
from googleapiclient.discovery import build
from google.auth import default
import numpy as np

def clean_data(df):
    """Clean data for Google Sheets export"""
    # Convert NaN to empty strings
    df = df.replace({np.nan: ''})

    # Clean strings - remove problematic characters
    for column in df.columns:
        if df[column].dtype == 'object':  # If column contains strings
            df[column] = df[column].str.replace('\n', ' ')  # Replace newlines with spaces
            df[column] = df[column].str.replace('\r', '')   # Remove carriage returns

    return df

def upload_to_sheets():
    # Authenticate
    auth.authenticate_user()

    # Get credentials
    creds, _ = default()

    # Read and clean the CSV
    df = pd.read_csv('movements.csv')
    df = clean_data(df)

    # Create the Sheets API service
    service = build('sheets', 'v4', credentials=creds)

    # Create new spreadsheet
    spreadsheet = {
        'properties': {
            'title': 'Gymnastics Movements Library'
        }
    }
    spreadsheet = service.spreadsheets().create(body=spreadsheet).execute()
    spreadsheet_id = spreadsheet['spreadsheetId']

    # Prepare the data
    values = [df.columns.tolist()]  # Header row

    # Convert DataFrame to list of lists, ensuring all values are strings
    data_values = df.astype(str).values.tolist()
    values.extend(data_values)

    # Update the spreadsheet
    body = {
        'values': values
    }

    # Calculate the range based on data size
    num_rows = len(values)
    num_cols = len(values[0])
    last_col = chr(ord('A') + num_cols - 1)  # Convert column number to letter
    range_name = f'Sheet1!A1:{last_col}{num_rows}'

    service.spreadsheets().values().update(
        spreadsheetId=spreadsheet_id,
        range=range_name,
        valueInputOption='RAW',
        body=body
    ).execute()

    # Format the spreadsheet
    requests = [
        # Format header row
        {
            "repeatCell": {
                "range": {
                    "sheetId": 0,
                    "startRowIndex": 0,
                    "endRowIndex": 1
                },
                "cell": {
                    "userEnteredFormat": {
                        "backgroundColor": {"red": 0.8, "green": 0.8, "blue": 0.8},
                        "textFormat": {"bold": True}
                    }
                },
                "fields": "userEnteredFormat(backgroundColor,textFormat)"
            }
        },
        # Freeze header row
        {
            "updateSheetProperties": {
                "properties": {
                    "sheetId": 0,
                    "gridProperties": {
                        "frozenRowCount": 1
                    }
                },
                "fields": "gridProperties.frozenRowCount"
            }
        }
    ]

    service.spreadsheets().batchUpdate(
        spreadsheetId=spreadsheet_id,
        body={"requests": requests}
    ).execute()

    print(f"\nSpreadsheet created successfully!")
    print(f"URL: https://docs.google.com/spreadsheets/d/{spreadsheet_id}")
    return spreadsheet_id

# Run the function
try:
    spreadsheet_id = upload_to_sheets()
except Exception as e:
    print(f"Error: {str(e)}")
    # Load and display the first few rows of data for debugging
    df = pd.read_csv('movements.csv')
    print("\nFirst few rows of data:")
    print(df.head())
# Out:
# Spreadsheet created successfully!
# URL: https://docs.google.com/spreadsheets/d/1--n2cwFA77sVk45rZ8l6lPHjvcfaewV7FkQp_ym44jk

# %%
import pandas as pd
import numpy as np

def analyze_movement_data():
    # Read the CSV file
    df = pd.read_csv('movements.csv')

    # Basic cleanup
    # Replace NaN with empty strings for text fields
    text_columns = ['title', 'instructions', 'movement_url', 'category', 'apparatus', 'movement_type']
    df[text_columns] = df[text_columns].fillna('')

    # Create separate dataframes for different views

    # 1. Main movement data
    movement_info = df[['title', 'category', 'apparatus', 'movement_type', 'instructions']]
    movement_info.to_csv('movement_info.csv', index=False)

    # 2. Video sources
    video_sources = df[['title', 'video_src_small', 'video_src_medium', 'video_src_large']]
    # Add a column indicating if any video source is available
    video_sources['has_video'] = video_sources[['video_src_small', 'video_src_medium', 'video_src_large']].notna().any(axis=1)
    video_sources.to_csv('video_sources.csv', index=False)

    # Print analysis
    print("\nData Analysis:")
    print("-" * 50)
    print("\nCategories:")
    print(df['category'].value_counts())

    print("\nApparatus:")
    print(df['apparatus'].value_counts())

    print("\nMovements with videos:")
    print(f"Total movements: {len(df)}")
    print(f"Movements with any video: {video_sources['has_video'].sum()}")
    print(f"Coverage: {(video_sources['has_video'].sum() / len(df) * 100):.1f}%")

    # Look for patterns in missing videos
    missing_videos = df[~video_sources['has_video']]
    print("\nCategories of movements missing videos:")
    print(missing_videos['category'].value_counts())

    # Export Google Sheets ready version
    # Combine most relevant fields
    sheets_df = df[[
        'title',
        'category',
        'apparatus',
        'movement_type',
        'instructions',
        'video_src_small',  # Include all video sources so you can choose which to use
        'video_src_medium',
        'video_src_large'
    ]].copy()

    # Sort by category and title for better organization
    sheets_df = sheets_df.sort_values(['category', 'title'])

    # Export to CSV
    sheets_df.to_csv('movements_for_sheets.csv', index=False)

    print("\nFiles created:")
    print("1. movement_info.csv - Basic movement information")
    print("2. video_sources.csv - Video source URLs")
    print("3. movements_for_sheets.csv - Formatted for Google Sheets import")

if __name__ == "__main__":
    analyze_movement_data()
# Out:
# Data Analysis:
# --------------------------------------------------
#
# Categories:
# category
# Functional            112
# Skill                  70
# Strength               37
# FunctionalSkill        10
# FunctionalStrength      1
# Name: count, dtype: int64
#
# Apparatus:
# apparatus
# Floor                   109
# High Bar                 37
# Rings                    33
# P-Bars                   23
# Box                      16
# Dumbbells                 6
# Pommel HorseMushroom      3
# Jump Rope                 2
# U-BarsHigh Bar            1
# Name: count, dtype: int64
#
# Movements with videos:
# Total movements: 230
# Movements with any video: 20
# Coverage: 8.7%
#
# Categories of movements missing videos:
# category
# Functional            101
# Skill                  64
# Strength               35
# FunctionalSkill         9
# FunctionalStrength      1
# Name: count, dtype: int64
#
# Files created:
# 1. movement_info.csv - Basic movement information
# 2. video_sources.csv - Video source URLs
# 3. movements_for_sheets.csv - Formatted for Google Sheets import
# <ipython-input-33-97eaaaa422f4>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   video_sources['has_video'] = video_sources[['video_src_small', 'video_src_medium', 'video_src_large']].notna().any(axis=1)

# %% [markdown]
# # Progressions

# %%
# script for progressions

import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import random
import json
import re
from urllib.parse import urljoin

class ProgressionScraper:
    def __init__(self):
        self.wayback_base = "https://web.archive.org"
        self.base_url = f"{self.wayback_base}/web/20130817171412/http://gymnasticswod.com/progressions"
        self.progressions = []
        self.headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
            'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
            'Accept-Language': 'en-US,en;q=0.5',
            'Connection': 'keep-alive'
        }
        self.session = requests.Session()
        self.last_request_time = 0
        self.min_request_delay = 10  # Increased for full scrape
        self.processed_urls = set()

    def clean_text(self, text):
        """Clean text by removing navigation and pagination content"""
        # Remove common navigation patterns
        text = text.replace('Pages', '')
        text = text.replace('next ›', '')
        text = text.replace('last »', '')
        text = text.replace('« first', '')
        text = text.replace('‹ previous', '')
        text = text.replace('> view more progressions', '')

        # Remove page numbers
        text = re.sub(r'\d+\.\.\.', '', text)
        text = re.sub(r'\d+', '', text)

        # Clean up multiple spaces and line breaks
        text = ' '.join(text.split())
        return text

    def wait_between_requests(self):
        elapsed = time.time() - self.last_request_time
        if elapsed < self.min_request_delay:
            wait_time = self.min_request_delay - elapsed + random.uniform(2, 5)
            time.sleep(wait_time)
        self.last_request_time = time.time()

    def get_page_content(self, url, retry_count=5, initial_delay=30):  # Increased retries and delay
        if not url.startswith('http'):
            url = urljoin(self.wayback_base, url)
        for attempt in range(retry_count):
            try:
                self.wait_between_requests()
                print(f"Fetching: {url}")
                response = self.session.get(url, headers=self.headers, timeout=30)
                if response.status_code == 404:
                    print("Page not found (404)")
                    return None
                if response.status_code == 429:
                    delay = initial_delay * (attempt + 1)
                    print(f"Rate limited. Waiting {delay} seconds...")
                    time.sleep(delay)
                    continue
                response.raise_for_status()
                if response.status_code == 200:
                    return response.text
            except requests.RequestException as e:
                print(f"Attempt {attempt + 1} failed: {str(e)}")
                if attempt + 1 == retry_count:
                    print(f"Failed to fetch {url}")
                    return None
                delay = initial_delay * (2 ** attempt)
                print(f"Waiting {delay:.1f} seconds before retry...")
                time.sleep(delay)
        return None

    def parse_progression_rows(self, soup):
        progression_rows = soup.find_all('article', class_='node-progression')
        if not progression_rows:
            progression_rows = soup.find_all('div', class_=lambda x: x and 'post' in str(x).lower())
            if not progression_rows:
                progression_rows = soup.find_all('div', class_='art-post')
        return progression_rows

    def extract_video_source(self, progression_url):
        content = self.get_page_content(progression_url)
        if not content:
            return ''
        soup = BeautifulSoup(content, 'html.parser')
        iframes = soup.find_all('iframe')
        print(f"Found {len(iframes)} iframes")
        for iframe in iframes:
            src = iframe.get('src', '')
            if not src or 'donate' in src:
                continue
            if not src.startswith('http'):
                src = urljoin(self.wayback_base, src)
            if 'size=small' in src:
                print(f"Found small video source: {src}")
                return src
            elif 'size=medium' in src:
                print(f"Found medium video source: {src}")
                return src
        return ''

    def parse_metadata(self, text):
        """Enhanced metadata parser with better text cleaning"""
        metadata = {
            'category': 'skill',
            'type': '',
            'apparatus': '',
            'movement': ''
        }

        try:
            text = self.clean_text(text)

            if '|' in text:
                parts = [p.strip() for p in text.split('|')]
                for part in parts:
                    for key in ['Category:', 'Type:', 'Apparatus:', 'Movement:']:
                        if key.lower() in part.lower():
                            value = part.split(key)[1].strip()
                            value = self.clean_text(value)
                            value = re.sub(r'(?<!^)(?=[A-Z])', ' ', value).strip()
                            metadata_key = key.lower().rstrip(':')
                            metadata[metadata_key] = value

            if metadata['category']:
                category = metadata['category'].lower().replace('progressions', '').strip()
                if category in {'skill', 'strength', 'functional'}:
                    metadata['category'] = category
                else:
                    text_lower = text.lower()
                    if any(word in text_lower for word in ['strength', 'power', 'conditioning']):
                        metadata['category'] = 'strength'
                    elif any(word in text_lower for word in ['skill', 'technique']):
                        metadata['category'] = 'skill'
                    elif any(word in text_lower for word in ['functional', 'movement', 'mobility']):
                        metadata['category'] = 'functional'
                    else:
                        metadata['category'] = 'skill'

        except Exception as e:
            print(f"Error parsing metadata text: {text}")
            print(f"Error: {str(e)}")

        return metadata

    def parse_progression(self, progression_row):
        try:
            title_h2 = progression_row.find(['h1', 'h2', 'h3'],
                class_=lambda x: x and ('postheader' in str(x).lower() or 'title' in str(x).lower()))

            if title_h2:
                title_link = title_h2.find('a')
            else:
                title_link = progression_row.find('a', class_=lambda x: x and 'title' in str(x).lower())

            if not title_link:
                return None

            progression_title = title_link.text.strip()
            progression_url = title_link['href']

            if progression_url in self.processed_urls:
                print(f"Skipping duplicate progression: {progression_title}")
                return None

            self.processed_urls.add(progression_url)
            print(f"\nFound progression: {progression_title}")

            content_div = progression_row.find('div', class_=lambda x: x and
                ('postcontent' in str(x).lower() or 'content' in str(x).lower()))

            metadata = {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
            instructions = []

            if content_div:
                metadata_p = content_div.find('p', text=lambda x: x and ('Category:' in x or 'Type:' in x))
                if metadata_p:
                    metadata = self.parse_metadata(metadata_p.get_text())
                    metadata_p.decompose()

                for p in content_div.find_all(['p']):
                    text = self.clean_text(p.get_text(strip=True))
                    if text and not any(key in text for key in ['Category:', 'Type:', 'Apparatus:', 'Movement:']):
                        instructions.append(text)

            full_url = urljoin(self.wayback_base, progression_url)
            video_src = self.extract_video_source(full_url)

            print(f"Extracted metadata: {metadata}")
            print(f"Instructions length: {len(instructions)}")

            progression_data = {
                'title': progression_title,
                'instructions': '\n'.join(instructions),
                'movement_url': progression_url,
                'category': metadata['category'],
                'type': metadata['type'],
                'apparatus': metadata['apparatus'],
                'movement': metadata['movement'],
                'video_src': video_src
            }

            print(f"Progression category: {progression_data['category']}")
            return progression_data

        except Exception as e:
            print(f"Error parsing progression: {str(e)}")
            return None

    def scrape_progressions(self, max_pages=None, start_page=0):  # Changed max_pages to None for full scrape
        page = start_page
        wanted_categories = {'strength', 'skill', 'functional'}

        while True:
            if max_pages is not None and page >= start_page + max_pages:
                print(f"Reached maximum number of pages ({max_pages})")
                break

            url = self.base_url
            if page > 0:
                url += f"?&&&sort_by=title&sort_order=ASC&items_per_page=10&page={page}"

            print(f"\nProcessing progressions page {page}")
            content = self.get_page_content(url)

            if not content:
                break

            soup = BeautifulSoup(content, 'html.parser')
            progression_rows = self.parse_progression_rows(soup)

            print(f"\nFound {len(progression_rows)} potential progression rows")

            if not progression_rows:
                print(f"No progressions found on page {page}")
                break

            progressions_added = 0
            for row in progression_rows:
                progression_data = self.parse_progression(row)
                if progression_data:
                    categories = [cat.strip().lower() for cat in progression_data['category'].split(',')]
                    if any(wanted in categories for wanted in wanted_categories):
                        self.progressions.append(progression_data)
                        progressions_added += 1
                        print(f"Added progression: {progression_data['title']}")
                    else:
                        print(f"Skipping progression with categories: {categories}")

            self.save_progress()
            print(f"Added {progressions_added} progressions from page {page}")
            print(f"Total items scraped: {len(self.progressions)}")

            page += 1
            delay = random.uniform(10, 15)  # Increased delay
            print(f"Waiting {delay:.1f} seconds before next page...")
            time.sleep(delay)

    def save_progress(self, filename='progressions_progress.json'):
        with open(filename, 'w') as f:
            json.dump(self.progressions, f)
        print(f"Progress saved to {filename}")

    def load_progress(self, filename='progressions_progress.json'):
        try:
            with open(filename, 'r') as f:
                self.progressions = json.load(f)
            print(f"Loaded {len(self.progressions)} progressions from {filename}")
        except FileNotFoundError:
            print("No progress file found, starting fresh")

    def save_to_csv(self, filename='progressions.csv'):
        if not self.progressions:
            print("No progressions to save!")
            return
        df = pd.DataFrame(self.progressions)
        df.to_csv(filename, index=False)
        print(f"\nSaved {len(self.progressions)} progressions to {filename}")
        for column in df.columns:
            non_empty = df[column].notna().sum()
            print(f"{column}: {non_empty}/{len(df)} rows have data ({(non_empty/len(df)*100):.1f}%)")

def main():
    scraper = ProgressionScraper()
    try:
        print("Starting progressions scrape...")
        # Load any existing progress
        scraper.load_progress()
        # Run full scrape with no page limit
        scraper.scrape_progressions(max_pages=None)
        scraper.save_to_csv()
    except KeyboardInterrupt:
        print("\nScraping interrupted by user!")
        scraper.save_to_csv('progressions_partial.csv')
        print("Partial results saved!")
    except Exception as e:
        print(f"\nAn error occurred: {str(e)}")
        import traceback
        traceback.print_exc()
        scraper.save_to_csv('progressions_error.csv')
        print("Partial results saved due to error!")

if __name__ == "__main__":
    main()
# Out:
# Starting progressions scrape...
# No progress file found, starting fresh
#
# Processing progressions page 0
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions
#
# Found 153 potential progression rows
#
# Found progression: Air Squat Progression Pt.1
# <ipython-input-3-c1b196169204>:183: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   metadata_p = content_div.find('p', text=lambda x: x and ('Category:' in x or 'Type:' in x))
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/air-squat-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130824210306if_/http://gymnasticswod.com/content/SQ00022?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 14
# Progression category: skill
# Added progression: Air Squat Progression Pt.1
# Skipping duplicate progression: Air Squat Progression Pt.1
# Skipping duplicate progression: Air Squat Progression Pt.1
# Skipping duplicate progression: Air Squat Progression Pt.1
# Skipping duplicate progression: Air Squat Progression Pt.1
# Skipping duplicate progression: Air Squat Progression Pt.1
# Skipping duplicate progression: Air Squat Progression Pt.1
#
# Found progression: Air Squat Progression Pt.2
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/air-squat-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130909034659if_/http://gymnasticswod.com/content/SQ00023?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Air Squat Progression Pt.2
# Skipping duplicate progression: Air Squat Progression Pt.2
# Skipping duplicate progression: Air Squat Progression Pt.2
#
# Found progression: Air Squat Progression Pt.3
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/air-squat-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130812145357if_/http://gymnasticswod.com/content/SQ00024?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Air Squat Progression Pt.3
# Skipping duplicate progression: Air Squat Progression Pt.3
# Skipping duplicate progression: Air Squat Progression Pt.3
#
# Found progression: Back Extension Roll Progression Pt.1
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/back-extension-roll-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130813070540if_/http://gymnasticswod.com/content/p01074?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Back Extension Roll Progression Pt.1
# Skipping duplicate progression: Back Extension Roll Progression Pt.1
# Skipping duplicate progression: Back Extension Roll Progression Pt.1
#
# Found progression: Back Extension Roll Progression Pt.2
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/back-extension-roll-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817205839if_/http://gymnasticswod.com/content/ac00003?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Back Extension Roll Progression Pt.2
# Skipping duplicate progression: Back Extension Roll Progression Pt.2
# Skipping duplicate progression: Back Extension Roll Progression Pt.2
#
# Found progression: Back Extension Roll Progression Pt.3
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/back-extension-roll-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130901235205if_/http://gymnasticswod.com/content/ac00004?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Back Extension Roll Progression Pt.3
# Skipping duplicate progression: Back Extension Roll Progression Pt.3
# Skipping duplicate progression: Back Extension Roll Progression Pt.3
#
# Found progression: Backward Roll on Rings Progression
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/backward-roll-rings-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817163551if_/http://gymnasticswod.com/content/r00045?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Backward Roll on Rings Progression
# Skipping duplicate progression: Backward Roll on Rings Progression
# Skipping duplicate progression: Backward Roll on Rings Progression
#
# Found progression: Backward Roll Progression Pt.1
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/backward-roll-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817223033if_/http://gymnasticswod.com/content/p01070?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Backward Roll Progression Pt.1
# Skipping duplicate progression: Backward Roll Progression Pt.1
# Skipping duplicate progression: Backward Roll Progression Pt.1
#
# Found progression: Backward Roll Progression Pt.2
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/backward-roll-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817165414if_/http://gymnasticswod.com/content/p01071?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Backward Roll Progression Pt.2
# Skipping duplicate progression: Backward Roll Progression Pt.2
# Skipping duplicate progression: Backward Roll Progression Pt.2
#
# Found progression: Backward Roll Progression Pt.3
# Fetching: https://web.archive.org/web/20130825070155/http://gymnasticswod.com/content/backward-roll-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817181251if_/http://gymnasticswod.com/content/p01073?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Backward Roll Progression Pt.3
# Skipping duplicate progression: Backward Roll Progression Pt.3
# Skipping duplicate progression: Backward Roll Progression Pt.3
# Progress saved to progressions_progress.json
# Added 10 progressions from page 0
# Total items scraped: 10
# Waiting 13.3 seconds before next page...
#
# Processing progressions page 1
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=1
#
# Found 153 potential progression rows
#
# Found progression: Bar Kip Progression
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bar-kip-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130816202140if_/http://gymnasticswod.com/content/v00059?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 16
# Progression category: skill
# Added progression: Bar Kip Progression
# Skipping duplicate progression: Bar Kip Progression
# Skipping duplicate progression: Bar Kip Progression
# Skipping duplicate progression: Bar Kip Progression
# Skipping duplicate progression: Bar Kip Progression
# Skipping duplicate progression: Bar Kip Progression
# Skipping duplicate progression: Bar Kip Progression
#
# Found progression: Bar Muscle Up Progression Pt.1
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bar-muscle-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130816051552if_/http://gymnasticswod.com/content/barmu00007?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Bar Muscle Up Progression Pt.1
# Skipping duplicate progression: Bar Muscle Up Progression Pt.1
# Skipping duplicate progression: Bar Muscle Up Progression Pt.1
#
# Found progression: Bar Muscle Up Progression Pt.2
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bar-muscle-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130815172435if_/http://gymnasticswod.com/content/barmu00008?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Bar Muscle Up Progression Pt.2
# Skipping duplicate progression: Bar Muscle Up Progression Pt.2
# Skipping duplicate progression: Bar Muscle Up Progression Pt.2
#
# Found progression: Bar Muscle Up Progression Pt.3
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bar-muscle-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130815213339if_/http://gymnasticswod.com/content/barmu00009?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Bar Muscle Up Progression Pt.3
# Skipping duplicate progression: Bar Muscle Up Progression Pt.3
# Skipping duplicate progression: Bar Muscle Up Progression Pt.3
#
# Found progression: Bar Pull Up Progression
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bar-pull-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130823095416if_/http://gymnasticswod.com/content/v00057?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bar Pull Up Progression
# Skipping duplicate progression: Bar Pull Up Progression
# Skipping duplicate progression: Bar Pull Up Progression
#
# Found progression: Blocking Movement for Quality Burpees
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/blocking-movement-quality-burpees
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130810042106if_/http://gymnasticswod.com/content/fh00124?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Blocking Movement for Quality Burpees
# Skipping duplicate progression: Blocking Movement for Quality Burpees
# Skipping duplicate progression: Blocking Movement for Quality Burpees
#
# Found progression: Blocking Movement for Quality Pull Ups
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/blocking-movement-quality-pull-ups
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817012315if_/http://gymnasticswod.com/content/fh00125?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Blocking Movement for Quality Pull Ups
# Skipping duplicate progression: Blocking Movement for Quality Pull Ups
# Skipping duplicate progression: Blocking Movement for Quality Pull Ups
#
# Found progression: Bodyweight Training for Power Athletes
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bodyweight-training-power-athletes
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130722014340if_/http://gymnasticswod.com/content/bw-power?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bodyweight Training for Power Athletes
# Skipping duplicate progression: Bodyweight Training for Power Athletes
# Skipping duplicate progression: Bodyweight Training for Power Athletes
#
# Found progression: Bridge Progressions Pt.1
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bridge-progressions-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130818224823if_/http://gymnasticswod.com/content/p00029?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bridge Progressions Pt.1
# Skipping duplicate progression: Bridge Progressions Pt.1
# Skipping duplicate progression: Bridge Progressions Pt.1
#
# Found progression: Bridge Progressions Pt.2
# Fetching: https://web.archive.org/web/20130817211725/http://gymnasticswod.com/content/bridge-progressions-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130818212050if_/http://gymnasticswod.com/content/p00031?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bridge Progressions Pt.2
# Skipping duplicate progression: Bridge Progressions Pt.2
# Skipping duplicate progression: Bridge Progressions Pt.2
# Progress saved to progressions_progress.json
# Added 10 progressions from page 1
# Total items scraped: 20
# Waiting 11.0 seconds before next page...
#
# Processing progressions page 2
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=2
#
# Found 153 potential progression rows
#
# Found progression: Bridge Progressions Pt.3
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/bridge-progressions-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130818191501if_/http://gymnasticswod.com/content/p00032?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 13
# Progression category: skill
# Added progression: Bridge Progressions Pt.3
# Skipping duplicate progression: Bridge Progressions Pt.3
# Skipping duplicate progression: Bridge Progressions Pt.3
# Skipping duplicate progression: Bridge Progressions Pt.3
# Skipping duplicate progression: Bridge Progressions Pt.3
# Skipping duplicate progression: Bridge Progressions Pt.3
# Skipping duplicate progression: Bridge Progressions Pt.3
#
# Found progression: Bridge Progressions Pt.4
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/bridge-progressions-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130818182345if_/http://gymnasticswod.com/content/p00034?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bridge Progressions Pt.4
# Skipping duplicate progression: Bridge Progressions Pt.4
# Skipping duplicate progression: Bridge Progressions Pt.4
#
# Found progression: Bridge Progressions Pt.5
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/bridge-progressions-pt5
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130818202458if_/http://gymnasticswod.com/content/p00035?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bridge Progressions Pt.5
# Skipping duplicate progression: Bridge Progressions Pt.5
# Skipping duplicate progression: Bridge Progressions Pt.5
#
# Found progression: Bridge Progressions Pt.6
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/bridge-progressions-pt6
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130818232139if_/http://gymnasticswod.com/content/p00037?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Bridge Progressions Pt.6
# Skipping duplicate progression: Bridge Progressions Pt.6
# Skipping duplicate progression: Bridge Progressions Pt.6
#
# Found progression: Burpee Skill Transfer Pt.1
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/burpee-skill-transfer-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828015402if_/http://gymnasticswod.com/content/bp00000?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Burpee Skill Transfer Pt.1
# Skipping duplicate progression: Burpee Skill Transfer Pt.1
# Skipping duplicate progression: Burpee Skill Transfer Pt.1
#
# Found progression: Burpee Skill Transfer Pt.2
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/burpee-skill-transfer-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130827095549if_/http://gymnasticswod.com/content/bp00001?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Burpee Skill Transfer Pt.2
# Skipping duplicate progression: Burpee Skill Transfer Pt.2
# Skipping duplicate progression: Burpee Skill Transfer Pt.2
#
# Found progression: Burpee Skill Transfer Pt.3
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/burpee-skill-transfer-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130827093551if_/http://gymnasticswod.com/content/bp00002?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Burpee Skill Transfer Pt.3
# Skipping duplicate progression: Burpee Skill Transfer Pt.3
# Skipping duplicate progression: Burpee Skill Transfer Pt.3
#
# Found progression: Burpee Skill Transfer Pt.4
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/burpee-skill-transfer-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130827084721if_/http://gymnasticswod.com/content/bp00003?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Burpee Skill Transfer Pt.4
# Skipping duplicate progression: Burpee Skill Transfer Pt.4
# Skipping duplicate progression: Burpee Skill Transfer Pt.4
#
# Found progression: Burpee Skill Transfer Pt.5
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/burpee-skill-transfer-pt5
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130819050437if_/http://gymnasticswod.com/content/bp00004?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Burpee Skill Transfer Pt.5
# Skipping duplicate progression: Burpee Skill Transfer Pt.5
# Skipping duplicate progression: Burpee Skill Transfer Pt.5
#
# Found progression: Burpee Skill Transfer Pt.6
# Fetching: https://web.archive.org/web/20130817173928/http://gymnasticswod.com/content/burpee-skill-transfer-pt6
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130808224609if_/http://gymnasticswod.com/content/bp00006?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Burpee Skill Transfer Pt.6
# Skipping duplicate progression: Burpee Skill Transfer Pt.6
# Skipping duplicate progression: Burpee Skill Transfer Pt.6
# Progress saved to progressions_progress.json
# Added 10 progressions from page 2
# Total items scraped: 30
# Waiting 10.2 seconds before next page...
#
# Processing progressions page 3
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=3
#
# Found 153 potential progression rows
#
# Found progression: Butterfly Pull Up Progression Pt.1
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/butterfly-pull-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130825130738if_/http://gymnasticswod.com/content/bpu00021?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 21
# Progression category: skill
# Added progression: Butterfly Pull Up Progression Pt.1
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.1
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.1
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.1
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.1
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.1
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.1
#
# Found progression: Butterfly Pull Up Progression Pt.2
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/butterfly-pull-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130812082747if_/http://gymnasticswod.com/content/bpu00022?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Butterfly Pull Up Progression Pt.2
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.2
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.2
#
# Found progression: Butterfly Pull Up Progression Pt.3
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/butterfly-pull-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130819091029if_/http://gymnasticswod.com/content/bpu00023?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Butterfly Pull Up Progression Pt.3
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.3
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.3
#
# Found progression: Butterfly Pull Up Progression Pt.4
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/butterfly-pull-progression-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130817030212if_/http://gymnasticswod.com/content/bpu00024?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Butterfly Pull Up Progression Pt.4
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.4
# Skipping duplicate progression: Butterfly Pull Up Progression Pt.4
#
# Found progression: Cartwheel Progression Pt.1
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/cartwheel-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130825065528if_/http://gymnasticswod.com/content/cw00000?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Cartwheel Progression Pt.1
# Skipping duplicate progression: Cartwheel Progression Pt.1
# Skipping duplicate progression: Cartwheel Progression Pt.1
#
# Found progression: Cartwheel Progression Pt.2
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/cartwheel-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130902063144if_/http://gymnasticswod.com/content/cw00001?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Cartwheel Progression Pt.2
# Skipping duplicate progression: Cartwheel Progression Pt.2
# Skipping duplicate progression: Cartwheel Progression Pt.2
#
# Found progression: Cartwheel Progression Pt.3
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/cartwheel-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20131008010012if_/http://gymnasticswod.com/content/cw00002?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Cartwheel Progression Pt.3
# Skipping duplicate progression: Cartwheel Progression Pt.3
# Skipping duplicate progression: Cartwheel Progression Pt.3
#
# Found progression: Cartwheel Progression Pt.4
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/cartwheel-progression-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20131008010045if_/http://gymnasticswod.com/content/cw00003?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Cartwheel Progression Pt.4
# Skipping duplicate progression: Cartwheel Progression Pt.4
# Skipping duplicate progression: Cartwheel Progression Pt.4
#
# Found progression: CrossFit Games 2012 Regionals Breakdown Event 1
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/crossfit-games-2012-regionals-breakdown-event-1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130815022127if_/http://gymnasticswod.com/content/2012CFG-WOD1?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games 2012 Regionals Breakdown Event 1
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 1
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 1
#
# Found progression: CrossFit Games 2012 Regionals Breakdown Event 2
# Fetching: https://web.archive.org/web/20130817150112/http://gymnasticswod.com/content/crossfit-games-2012-regionals-breakdown-event-2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130917132459if_/http://gymnasticswod.com/content/2012CFG-WOD2?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games 2012 Regionals Breakdown Event 2
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 2
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 2
# Progress saved to progressions_progress.json
# Added 10 progressions from page 3
# Total items scraped: 40
# Waiting 13.4 seconds before next page...
#
# Processing progressions page 4
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=4
#
# Found 153 potential progression rows
#
# Found progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-2012-regionals-breakdown-event-3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130822193314if_/http://gymnasticswod.com/content/2012CFG-WOD3?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 21
# Progression category: skill
# Added progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 3
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 3
#
# Found progression: CrossFit Games 2012 Regionals Breakdown Event 4
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-2012-regionals-breakdown-event-4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130824105842if_/http://gymnasticswod.com/content/2012CFG-WOD4?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games 2012 Regionals Breakdown Event 4
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 4
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 4
#
# Found progression: CrossFit Games 2012 Regionals Breakdown Event 5
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-2012-regionals-breakdown-event-5
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130917203101if_/http://gymnasticswod.com/content/2012CFG-WOD5?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games 2012 Regionals Breakdown Event 5
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 5
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 5
#
# Found progression: CrossFit Games 2012 Regionals Breakdown Event 6
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-2012-regionals-breakdown-event-6
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130822162920if_/http://gymnasticswod.com/content/2012CFG-WOD6?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games 2012 Regionals Breakdown Event 6
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 6
# Skipping duplicate progression: CrossFit Games 2012 Regionals Breakdown Event 6
#
# Found progression: CrossFit Games Breakdown - Regionals Workouts - Pt.1
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-breakdown-regionals-workouts-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130822183153if_/http://gymnasticswod.com/content/cfgr00074?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 3
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Regionals Workouts - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.1
#
# Found progression: CrossFit Games Breakdown - Regionals Workouts - Pt.2
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-breakdown-regionals-workouts-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130822190415if_/http://gymnasticswod.com/content/cfgr00077?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Regionals Workouts - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.2
#
# Found progression: CrossFit Games Breakdown - Regionals Workouts - Pt.3
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-breakdown-regionals-workouts-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130824131809if_/http://gymnasticswod.com/content/cfgr00083?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Regionals Workouts - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.3
#
# Found progression: CrossFit Games Breakdown - Regionals Workouts - Pt.4
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-breakdown-regionals-workouts-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20131001125030if_/http://gymnasticswod.com/content/cfgr00089?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Regionals Workouts - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.4
#
# Found progression: CrossFit Games Breakdown - Regionals Workouts - Pt.5
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-breakdown-regionals-workouts-pt5
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130824112440if_/http://gymnasticswod.com/content/cfgr00091?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Regionals Workouts - Pt.5
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.5
# Skipping duplicate progression: CrossFit Games Breakdown - Regionals Workouts - Pt.5
#
# Found progression: CrossFit Games Breakdown - Week 1 Workout - Pt.1
# Fetching: https://web.archive.org/web/20130817163217/http://gymnasticswod.com/content/crossfit-games-breakdown-week-1-workout-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130929214551if_/http://gymnasticswod.com/content/cfgm00097?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 1 Workout - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.1
# Progress saved to progressions_progress.json
# Added 10 progressions from page 4
# Total items scraped: 50
# Waiting 14.8 seconds before next page...
#
# Processing progressions page 5
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=5
#
# Found 153 potential progression rows
#
# Found progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-1-workout-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130822202038if_/http://gymnasticswod.com/content/cfgm00098?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 11
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.2
#
# Found progression: CrossFit Games Breakdown - Week 1 Workout - Pt.3
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-1-workout-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130824192227if_/http://gymnasticswod.com/content/cfgm00099?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 1 Workout - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.3
#
# Found progression: CrossFit Games Breakdown - Week 1 Workout - Pt.4
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-1-workout-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130827021611if_/http://gymnasticswod.com/content/cfgm00103?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 1 Workout - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Week 1 Workout - Pt.4
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Follow Up
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-follow
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828212806if_/http://gymnasticswod.com/content/cfg00200?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Follow Up
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Follow Up
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Follow Up
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.1
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20131004123610if_/http://gymnasticswod.com/content/cfg00163?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.1
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.2
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130829053925if_/http://gymnasticswod.com/content/cfg00164?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.2
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.3
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828085650if_/http://gymnasticswod.com/content/cfg00165?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.3
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.4
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828094558if_/http://gymnasticswod.com/content/cfg00166?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.4
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.5
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt5
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828191121if_/http://gymnasticswod.com/content/cfg00167b?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.5
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.5
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.5
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.6
# Fetching: https://web.archive.org/web/20130817185320/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt6
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828171319if_/http://gymnasticswod.com/content/cfg00168?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.6
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.6
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.6
# Progress saved to progressions_progress.json
# Added 10 progressions from page 5
# Total items scraped: 60
# Waiting 10.6 seconds before next page...
#
# Processing progressions page 6
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=6
#
# Found 153 potential progression rows
#
# Found progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Fetching: https://web.archive.org/web/20130817194626/http://gymnasticswod.com/content/crossfit-games-breakdown-week-2-workout-pt7
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130822183030if_/http://gymnasticswod.com/content/cfg00169?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 11
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
# Skipping duplicate progression: CrossFit Games Breakdown - Week 2 Workout - Pt.7
#
# Found progression: CrossFit Games Breakdown - Week 3 Workout - Pt.1
# Fetching: https://web.archive.org/web/20130817194626/http://gymnasticswod.com/content/crossfit-games-breakdown-week-3-workout-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130722205417if_/http://gymnasticswod.com/content/cfg00193?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 3 Workout - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.1
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.1
#
# Found progression: CrossFit Games Breakdown - Week 3 Workout - Pt.2
# Fetching: https://web.archive.org/web/20130817194626/http://gymnasticswod.com/content/crossfit-games-breakdown-week-3-workout-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130722224237if_/http://gymnasticswod.com/content/cfg00194?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 3 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.2
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.2
#
# Found progression: CrossFit Games Breakdown - Week 3 Workout - Pt.3
# Fetching: https://web.archive.org/web/20130817194626/http://gymnasticswod.com/content/crossfit-games-breakdown-week-3-workout-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130824124302if_/http://gymnasticswod.com/content/cfg00195?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 3 Workout - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.3
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.3
#
# Found progression: CrossFit Games Breakdown - Week 3 Workout - Pt.4
# Fetching: https://web.archive.org/web/20130817194626/http://gymnasticswod.com/content/crossfit-games-breakdown-week-3-workout-pt4
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130828054748if_/http://gymnasticswod.com/content/cfg00196?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 3 Workout - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.4
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.4
#
# Found progression: CrossFit Games Breakdown - Week 3 Workout - Pt.5
# Fetching: https://web.archive.org/web/20130817194626/http://gymnasticswod.com/content/crossfit-games-breakdown-week-3-workout-pt5
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20131001064408if_/http://gymnasticswod.com/content/cfg00197?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: CrossFit Games Breakdown - Week 3 Workout - Pt.5
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.5
# Skipping duplicate progression: CrossFit Games Breakdown - Week 3 Workout - Pt.5
#
# Found progression: CrossFit Games Breakdown - Week 3 Workout - Pt.6
# ...
# Added progression: Kick Up to Handstand Progression - Pt.2
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.2
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.2
# Progress saved to progressions_progress.json
# Added 10 progressions from page 14
# Total items scraped: 150
# Waiting 13.0 seconds before next page...
#
# Processing progressions page 15
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=15
#
# Found 153 potential progression rows
#
# Found progression: Kick Up to Handstand Progression - Pt.3
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kick-handstand-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130302101754if_/http://gymnasticswod.com/content/p01059?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 16
# Progression category: skill
# Added progression: Kick Up to Handstand Progression - Pt.3
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.3
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.3
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.3
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.3
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.3
# Skipping duplicate progression: Kick Up to Handstand Progression - Pt.3
#
# Found progression: Kip Up to Support Progression Pt.1
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kip-support-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130211043822if_/http://gymnasticswod.com/content/ks00006?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Kip Up to Support Progression Pt.1
# Skipping duplicate progression: Kip Up to Support Progression Pt.1
# Skipping duplicate progression: Kip Up to Support Progression Pt.1
#
# Found progression: Kip Up to Support Progression Pt.2
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kip-support-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130218065858if_/http://gymnasticswod.com/content/ks00007?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Kip Up to Support Progression Pt.2
# Skipping duplicate progression: Kip Up to Support Progression Pt.2
# Skipping duplicate progression: Kip Up to Support Progression Pt.2
#
# Found progression: Kip Up to Support Progression Pt.3
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kip-support-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130224151426if_/http://gymnasticswod.com/content/ks00008?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Kip Up to Support Progression Pt.3
# Skipping duplicate progression: Kip Up to Support Progression Pt.3
# Skipping duplicate progression: Kip Up to Support Progression Pt.3
#
# Found progression: Kipping Dip on P-Bars Progression
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kipping-dip-p-bars-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130304231319if_/http://gymnasticswod.com/content/ps00018?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Kipping Dip on P-Bars Progression
# Skipping duplicate progression: Kipping Dip on P-Bars Progression
# Skipping duplicate progression: Kipping Dip on P-Bars Progression
#
# Found progression: Kipping Handstand Push Up Progression Pt.1
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kipping-handstand-push-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130221025233if_/http://gymnasticswod.com/content/hspu00004?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: Kipping Handstand Push Up Progression Pt.1
# Skipping duplicate progression: Kipping Handstand Push Up Progression Pt.1
# Skipping duplicate progression: Kipping Handstand Push Up Progression Pt.1
#
# Found progression: Kipping Pull Up Progression
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/kipping-pull-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130301231431if_/http://gymnasticswod.com/content/v00060?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: Kipping Pull Up Progression
# Skipping duplicate progression: Kipping Pull Up Progression
# Skipping duplicate progression: Kipping Pull Up Progression
#
# Found progression: L-Hang Pull Up Progression
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/l-hang-pull-progression
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130302235154if_/http://gymnasticswod.com/content/r00046?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: L-Hang Pull Up Progression
# Skipping duplicate progression: L-Hang Pull Up Progression
# Skipping duplicate progression: L-Hang Pull Up Progression
#
# Found progression: L-Seat Progression Pt.1
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/l-seat-progression-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130302074908if_/http://gymnasticswod.com/content/ls00011?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: L-Seat Progression Pt.1
# Skipping duplicate progression: L-Seat Progression Pt.1
# Skipping duplicate progression: L-Seat Progression Pt.1
#
# Found progression: L-Seat Progression Pt.2
# Fetching: https://web.archive.org/web/20130220104638/http://gymnasticswod.com/content/l-seat-progression-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130208083158if_/http://gymnasticswod.com/content/ls00012?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: L-Seat Progression Pt.2
# Skipping duplicate progression: L-Seat Progression Pt.2
# Skipping duplicate progression: L-Seat Progression Pt.2
# Progress saved to progressions_progress.json
# Added 10 progressions from page 15
# Total items scraped: 160
# Waiting 12.2 seconds before next page...
#
# Processing progressions page 16
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=16
#
# Found 153 potential progression rows
#
# Found progression: L-Seat Progression Pt.3
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/l-seat-progression-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130305004840if_/http://gymnasticswod.com/content/ls00013?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 28
# Progression category: skill
# Added progression: L-Seat Progression Pt.3
# Skipping duplicate progression: L-Seat Progression Pt.3
# Skipping duplicate progression: L-Seat Progression Pt.3
# Skipping duplicate progression: L-Seat Progression Pt.3
# Skipping duplicate progression: L-Seat Progression Pt.3
# Skipping duplicate progression: L-Seat Progression Pt.3
# Skipping duplicate progression: L-Seat Progression Pt.3
#
# Found progression: La Clase - Parte 1
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-clase-parte-1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130116233707if_/http://gymnasticswod.com/content/sp00116?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 6
# Progression category: skill
# Added progression: La Clase - Parte 1
# Skipping duplicate progression: La Clase - Parte 1
# Skipping duplicate progression: La Clase - Parte 1
#
# Found progression: La Clase - Parte 2
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-clase-parte-2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130210153539if_/http://gymnasticswod.com/content/sp00119?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 4
# Progression category: skill
# Added progression: La Clase - Parte 2
# Skipping duplicate progression: La Clase - Parte 2
# Skipping duplicate progression: La Clase - Parte 2
#
# Found progression: La Dominada Pt.1
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-dominada-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130210154036if_/http://gymnasticswod.com/content/sp00041?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: La Dominada Pt.1
# Skipping duplicate progression: La Dominada Pt.1
# Skipping duplicate progression: La Dominada Pt.1
#
# Found progression: La Dominada Pt.2
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-dominada-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130210153900if_/http://gymnasticswod.com/content/sp00043?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: La Dominada Pt.2
# Skipping duplicate progression: La Dominada Pt.2
# Skipping duplicate progression: La Dominada Pt.2
#
# Found progression: La Dominada Pt.3
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-dominada-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130117002405if_/http://gymnasticswod.com/content/sp00045?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: La Dominada Pt.3
# Skipping duplicate progression: La Dominada Pt.3
# Skipping duplicate progression: La Dominada Pt.3
#
# Found progression: La Flexión
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-flexi%C3%B3n
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130207045141if_/http://gymnasticswod.com/content/sp00123?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 2
# Progression category: skill
# Added progression: La Flexión
# Skipping duplicate progression: La Flexión
# Skipping duplicate progression: La Flexión
#
# Found progression: La Parada De Cabeza Pt.1
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-parada-de-cabeza-pt1
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130210154207if_/http://gymnasticswod.com/content/sp00052?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 4
# Progression category: skill
# Added progression: La Parada De Cabeza Pt.1
# Skipping duplicate progression: La Parada De Cabeza Pt.1
# Skipping duplicate progression: La Parada De Cabeza Pt.1
#
# Found progression: La Parada De Cabeza Pt.2
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-parada-de-cabeza-pt2
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130210154351if_/http://gymnasticswod.com/content/sp00053?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 3
# Progression category: skill
# Added progression: La Parada De Cabeza Pt.2
# Skipping duplicate progression: La Parada De Cabeza Pt.2
# Skipping duplicate progression: La Parada De Cabeza Pt.2
#
# Found progression: La Parada De Cabeza Pt.3
# Fetching: https://web.archive.org/web/20130220104838/http://gymnasticswod.com/content/la-parada-de-cabeza-pt3
# Found 4 iframes
# Found small video source: https://web.archive.org/web/20130210154529if_/http://gymnasticswod.com/content/sp00055?size=small
# Extracted metadata: {'category': 'skill', 'type': '', 'apparatus': '', 'movement': ''}
# Instructions length: 1
# Progression category: skill
# Added progression: La Parada De Cabeza Pt.3
# Skipping duplicate progression: La Parada De Cabeza Pt.3
# Skipping duplicate progression: La Parada De Cabeza Pt.3
# Progress saved to progressions_progress.json
# Added 10 progressions from page 16
# Total items scraped: 170
# Waiting 12.3 seconds before next page...
#
# Processing progressions page 17
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Attempt 1 failed: 500 Server Error: Internal Server Error for url: https://web.archive.org/web/20130722140015/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Waiting 30.0 seconds before retry...
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Attempt 2 failed: 500 Server Error: Internal Server Error for url: https://web.archive.org/web/20130722140015/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Waiting 60.0 seconds before retry...
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Attempt 3 failed: 500 Server Error: Internal Server Error for url: https://web.archive.org/web/20130722140015/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Waiting 120.0 seconds before retry...
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Attempt 4 failed: 500 Server Error: Internal Server Error for url: https://web.archive.org/web/20130722140015/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Waiting 240.0 seconds before retry...
# Fetching: https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Attempt 5 failed: 500 Server Error: Internal Server Error for url: https://web.archive.org/web/20130722140015/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
# Failed to fetch https://web.archive.org/web/20130817171412/http://gymnasticswod.com/progressions?&&&sort_by=title&sort_order=ASC&items_per_page=10&page=17
#
# Saved 170 progressions to progressions.csv
# title: 170/170 rows have data (100.0%)
# instructions: 170/170 rows have data (100.0%)
# movement_url: 170/170 rows have data (100.0%)
# category: 170/170 rows have data (100.0%)
# type: 170/170 rows have data (100.0%)
# apparatus: 170/170 rows have data (100.0%)
# movement: 170/170 rows have data (100.0%)
# video_src: 170/170 rows have data (100.0%)

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv('progressions.csv')

# Basic info about the dataset
print(f"Total number of progressions: {len(df)}")
print("\nColumns in the dataset:")
for column in df.columns:
    print(f"{column}: {df[column].notna().sum()} entries")

# Check categories distribution
print("\nCategory distribution:")
print(df['category'].value_counts())

# Check for duplicates
duplicates = df[df.duplicated(subset=['title'])]
print(f"\nNumber of duplicate titles: {len(duplicates)}")
# Out:
# Total number of progressions: 170
#
# Columns in the dataset:
# title: 170 entries
# instructions: 170 entries
# movement_url: 170 entries
# category: 170 entries
# type: 0 entries
# apparatus: 0 entries
# movement: 0 entries
# video_src: 170 entries
#
# Category distribution:
# category
# skill    170
# Name: count, dtype: int64
#
# Number of duplicate titles: 10

# %%
# Look at first few entries
print("\nFirst few entries:")
print(df[['title', 'category', 'video_src']].head())
# Out:
# First few entries:
#                                   title category  \
# 0            Air Squat Progression Pt.1    skill
# 1            Air Squat Progression Pt.2    skill
# 2            Air Squat Progression Pt.3    skill
# 3  Back Extension Roll Progression Pt.1    skill
# 4  Back Extension Roll Progression Pt.2    skill
#
#                                            video_src
# 0  https://web.archive.org/web/20130824210306if_/...
# 1  https://web.archive.org/web/20130909034659if_/...
# 2  https://web.archive.org/web/20130812145357if_/...
# 3  https://web.archive.org/web/20130813070540if_/...
# 4  https://web.archive.org/web/20130817205839if_/...

# %%
# exporting progressions to GSheets
from google.colab import drive, auth
from google.oauth2.credentials import Credentials
from google.auth.transport.requests import Request
from google.oauth2 import service_account
from google.colab import auth
from oauth2client.client import GoogleCredentials
import gspread
import pandas as pd
from google.auth import default

def upload_to_sheets():
    print("Setting up Google Sheets access...")
    drive.mount('/content/drive', force_remount=True)

    auth.authenticate_user()
    creds, _ = default()
    gc = gspread.authorize(creds)

    print("Reading and cleaning progressions data...")
    df = pd.read_csv('progressions.csv')

    # Create series and part information
    df['series'] = df['title'].apply(lambda x: x.split('Pt.')[0].strip() if 'Pt.' in x else x)
    df['part'] = df['title'].apply(lambda x: f"Part {x.split('Pt.')[1]}" if 'Pt.' in x else '')

    # Clean NaN values
    df['category'] = df['category'].fillna('Unspecified')
    df['type'] = df['type'].fillna('')
    df['apparatus'] = df['apparatus'].fillna('')
    df['movement'] = df['movement'].fillna('')
    df['instructions'] = df['instructions'].fillna('')

    print("\nCreating main spreadsheet...")
    workbook = gc.create('Gymnastics Progressions Database')

    print("Creating Overview sheet...")
    overview = workbook.sheet1
    overview.update_title('Overview')

    overview_data = [
        ['Gymnastics Progressions Database'],
        [''],
        ['Total Progressions:', str(len(df))],
        ['Total Unique Series:', str(len(df['series'].unique()))],
        [''],
        ['Progressions by Category'],
        ['Category', 'Count']
    ]

    category_counts = df['category'].value_counts()
    for category, count in category_counts.items():
        overview_data.append([category, str(count)])

    overview_data.extend([
        [''],
        ['Series with Multiple Parts'],
        ['Series', 'Number of Parts']
    ])

    series_counts = df['series'].value_counts()
    multi_part_series = series_counts[series_counts > 1]
    for series, count in multi_part_series.items():
        overview_data.append([series, str(count)])

    print("Updating Overview sheet...")
    overview.update('A1', overview_data)

    print("\nCreating All Progressions sheet...")
    all_progressions = workbook.add_worksheet(title='All Progressions', rows=len(df)+1, cols=9)

    # Prepare headers and data
    headers = ['Series', 'Part', 'Category', 'Type', 'Apparatus', 'Movement', 'Instructions', 'Video Link', 'Movement Link']

    # Create hyperlinks for videos and movement URLs
    df['video_link'] = df['video_src'].apply(lambda x: f'{x}' if pd.notna(x) and x != '' else '')
    df['movement_link'] = df['movement_url'].apply(lambda x: f'{x}, "View Details")' if pd.notna(x) and x != '' else '')

    # Convert DataFrame to list of lists
    all_data = [headers]
    all_data.extend(df[['series', 'part', 'category', 'type', 'apparatus', 'movement', 'instructions', 'video_link', 'movement_link']].values.tolist())

    print(f"Uploading data to All Progressions sheet...")
    all_progressions.update('A1', all_data)

    # Create category sheets
    for category in df['category'].unique():
        print(f"\nCreating sheet for {category}...")
        category_df = df[df['category'] == category]

        sheet_name = category.replace(' ', '_')[:100]  # Sheet names have character limits
        category_sheet = workbook.add_worksheet(title=sheet_name, rows=len(category_df)+1, cols=8)

        # Prepare category data
        category_data = [['Series', 'Part', 'Type', 'Apparatus', 'Movement', 'Instructions', 'Video', 'Details']]
        category_data.extend(category_df[['series', 'part', 'type', 'apparatus', 'movement', 'instructions', 'video_link', 'movement_link']].values.tolist())

        print(f"Uploading data to {category} sheet...")
        category_sheet.update('A1', category_data)

    # Format the sheets
    print("\nApplying formatting...")
    for worksheet in workbook.worksheets():
        worksheet.freeze(1, 0)  # Freeze first row
        worksheet.format('A1:Z1', {
            "backgroundColor": {"red": 0.9, "green": 0.9, "blue": 0.9},
            "textFormat": {"bold": True}
        })

    print("\nSpreadsheet creation complete!")
    print(f"Spreadsheet URL: {workbook.url}")

    # Share the spreadsheet
    workbook.share(None, perm_type='anyone', role='reader')

    return workbook.url

try:
    print("Starting Google Sheets upload...")
    spreadsheet_url = upload_to_sheets()
    print(f"\nYour spreadsheet is available at: {spreadsheet_url}")

except Exception as e:
    print(f"An error occurred: {str(e)}")
    import traceback
    traceback.print_exc()
# Out:
# Starting Google Sheets upload...
# Setting up Google Sheets access...
# Mounted at /content/drive
# Reading and cleaning progressions data...
#
# Creating main spreadsheet...
# Creating Overview sheet...
# Updating Overview sheet...
#
# Creating All Progressions sheet...
# <ipython-input-19-11d2f11f0d12>:66: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   overview.update('A1', overview_data)
# Uploading data to All Progressions sheet...
# <ipython-input-19-11d2f11f0d12>:83: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   all_progressions.update('A1', all_data)
# Creating sheet for skill...
# Uploading data to skill sheet...
# <ipython-input-19-11d2f11f0d12>:98: DeprecationWarning: The order of arguments in worksheet.update() has changed. Please pass values first and range_name secondor used named arguments (range_name=, values=)
#   category_sheet.update('A1', category_data)
# Applying formatting...
#
# Spreadsheet creation complete!
# Spreadsheet URL: https://docs.google.com/spreadsheets/d/1x6mLJEgQmwALqUk9hDmbvAfddK7DF2DjKf_TgcHWVy0
#
# Your spreadsheet is available at: https://docs.google.com/spreadsheets/d/1x6mLJEgQmwALqUk9hDmbvAfddK7DF2DjKf_TgcHWVy0
